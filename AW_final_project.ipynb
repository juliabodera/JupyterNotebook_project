# %% [markdown]
# # The role of vocabulary acquisition in English learning
# ## Academic Writing - Final Project

# %% [markdown]
# ### Introduction
#
# In this piece of work, I am going to focus on the role of vocabulary acquistion in English learning. I am going to answer the question if vocabulary is important in learning languages. However, the main aim of this essay is to practice using such tools as [Natural Language Toolkit (NLTK)](https://www.nltk.org/), [BeautifulSoup library](https://www.dataquest.io/blog/web-scraping-python-using-beautiful-soup/) to perform web scraping, and obviously, Python 3. At some point this essay might regard to linguistic analysis in particular, rather than to the topic of the role of vocabulary in learning languages. In this essay, the second language acquisition is mostly taken into account, since native speakers of a given language learn new vocabulary differently than foreign language learners.

# %% [markdown]
# ### Chapter 1.
#
# At first glance, it can be said that the question posed in the title is abstract. It is, indeed. As David A. Wilkins, British linguists, said:
#
# >without grammar, very little can be conveyed;
# >without vocabulary nothing can be conveyed.
#
# Therefore, without vocabulary, there is no language. It is not posibble to even imagine saying that you know a language, when actually you do not know any word. __Vocabulary the foundation of a language__. One could say that grammar is the most important department in learning, however, let's come back to the quote of Wilkins. We can communicate even if we just know a few words and have no understanding of grammar.
#
# To learn new vocabulary, we can choose various ways. Writing, reading, listening - basic comprehensive skills. Learners are free to choose whichever form they prefer to achieve their goal faster and more effectively. Let's look at some examples, showing the differences in efectiveness between aforementioned skills.

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
slices = [27, 30, 43]
titles = 'Listening', 'Writing', 'Reading'
explode = (0, 0, 0.1)
color = ['m', 'b', 'g']
plt.title("The best way to enlarge your vocabulary")
plt.pie(slices, labels = titles, startangle = 140, shadow = True, explode = explode, autopct = '%1.1f%%')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Therefore, we can see from this pie chart that reading is the most beneficial and the fastest way to improve your vocabulary. It does not matter, if you are a beginner or you are already an advanced learner; while reading, you come across various words. You have a few options here:
# 1. You look up the words you do not know in a dictionary.
# 2. You guess the meaning from the context.
# 3. You can just give up and find something else to read.
#
# No matter which option you choose (but let's skip the last one), you are still able to memorise those words, given you are working with them, you see them and you focus on them for a while. From [TextInspector](https://textinspector.com/vocabulary-in-language-learning/) we find out, that:
# > This connection between vocabulary size and second language attainment has been widely researched over the years. One of the most interesting of these was a 2010 study that discovered that a surprising 64% of variance in the reading score was due to vocabulary size.
#
# Not only can reading benefit you, but also entertain you.
#
# Moving on to another skill - writing. It is a way to practise your vocabulary and use words you have previously learnt. What is more, a larger vocabulary helps you express yourself more precisely. Nonetheless, as the least beneficial way to improve your vocabulary is listening. Theoretically, it is debatable. The problem with listening is the fact that considering you cannot see a particular piece of vocabulary, it is harder to recognise and decode the sounds, especially when you are at the very beginning of your adventure with a foreign language. Most people are visualisers and it does not make extracting the meaning any easier.

# %% [markdown]
# ### Chapter 2.
#
# Since we have discussed the possible ways to enlarge our vocabulary, let's start with some analysis. In this part I am going to analyse the article [*Learning Styles and Vocabulary Acquisition in Second Language: How the Brain Learns*](https://www.frontiersin.org/articles/10.3389/fpsyg.2015.01800/full#B23), written by Manuela Macedonia. I will be analysing which words are the most frequent in the article, POS-tagging, how many words each paragraph consists of. Basically, the main aim of this chapter is to work thorough natural language processing toolkits.

# %%
import requests
page = requests.get("https://www.frontiersin.org/articles/10.3389/fpsyg.2015.01800/full#B23")

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')

# %%
paragraphs = soup.find_all('p')

# %%
import nltk

# %%
for parts in paragraphs:
    text = parts.get_text().strip()
    if len(text) > 0:
        print("Each paragraph after web scraping: ", text)
# Out:
# Each paragraph after web scraping:  Impact Factor 2.067 | CiteScore 3.2More on impact ›
# Each paragraph after web scraping:  University of Navarra, Spain
# Each paragraph after web scraping:  University of Groningen, Netherlands
# Each paragraph after web scraping:  The editor and reviewers' affiliations are the latest provided on their Loop research profiles and may not reflect their situation at the time of review.
# Each paragraph after web scraping:  Suggest a Research Topic >
# Each paragraph after web scraping:  Suggest a Research Topic >
# Each paragraph after web scraping:  In recent years, foreign language education has been focussing on learning styles. However, despite the quantity of articles and practice books, websites on the topic, and investment in teacher training, there is no empirical evidence for the existence of learning styles. Furthermore, if one agrees that it is the brain that learns, there should be indicators in the brain for the existence of learning styles, anatomically, and/or functionally. This is not the case. In this paper, the validity and reliability of tests assessing learning styles are questioned. Thereafter, following on basics of cognitive neuroscience and experimental evidence it is argued that the natural way for the brain to learn words is by collecting multiple sensory and sensorimotor experiences. In fact, evidence-based literature in the domain of vocabulary acquisition demonstrates that the inclusion of multiple modalities leads to best results. Impoverished linguistic input by allowing only one modality, for example only acoustic or visual input—the so called learning style (Pashler et al., 2008) of the student—reduces the chances of acquiring words. Also, the article briefly outlines brain related factors that lead to high performance in vocabulary learning.
# Each paragraph after web scraping:  A closer look at the literature on learning styles shows a multitude of models that classify learners in different types. Despite differences (for reviews see Pashler et al., 2008; Romanelli et al., 2009; Kaminska, 2014), learning style models have a common base: they sustain that not all individuals learn the same way. One of them, the VARK model (Fleming, 2001), categorizes learners as aural, visual, kinaesthetic, haptic, and learners who prefer to read and write. In second language instruction, this view implicates that a person classified as aural should learn vocabulary items by means of acoustic training, whereas a visual learner would optimize the learning outcome by reading and/or using flash cards that illustrate the word's semantics. However, despite being very popular, this position is not evidence-based. It is simply taken for granted with the intention to promote the learners' capacities. Also, it is not proven that assessments administered to determine the learning style to which a person belongs are valid and reliable. Nobody has proven that they measure what they claim. One major issue connected to these tests is that they are based on self-report. It has been suggested that in self-reports, subjects might lack introspection and that yes or no answers on personal experiences may not mirror reality (Paulhus and Vazire, 2007; Vazire and Solomon, 2015). Furthermore, there is an additional aspect to consider: tests on learning styles—supposed they were valid and reliable—might tell how a learner likes to acquire information on a conscious level. However, this does not automatically imply that preference leads to best learning outcome. In Western countries, L2 instructions make large use of listening activities, reading and writing exercises for vocabulary learning. These procedures are well-known to learners. When asked, learners may indicate them as preferences due to familiarity. Also, learners might not be informed about other possibilities of acquiring vocabulary and/or have not tested them. For example, learners might not know that performing gestures while learning words enhances retention compared with audio-visual learning (Macedonia, 2014). Hence, in order to define whether learners might acquire L2 words with one or another modality better, a large population should be tested in all modalities at different points in time. Testing should occur with vocabulary items that are controlled for familiarity, length, and associative features. If the population proves to repeatedly learn vocabulary items with visual input better than with aural or kinaesthetic and haptic input, then this population might have a learning style and the test would be valid. But such studies have yet to be conducted. Reviews on learning styles often come to the insight that best practice employs a variety of learning styles (Romanelli et al., 2009). However, despite the arguments above and the lack of a scientific basis, practitioners take learning styles seriously. In L2 lessons, teachers endeavor to offer “individualized” learning tools with the intention to augment learning outcomes in vocabulary acquisition.
# Each paragraph after web scraping:  Considering that it is the brain that learns, it is worth asking what happens at this level during word learning in L2. On average, if learners display no congenital or acquired neurological impairments, they should possess similar learning potentials. Billions of neurons process and store the incoming information in large networks. They include areas of the brain that deal with language (Friederici, 2011), cognitive control (Abutalebi, 2008), semantic processing (Binder et al., 2009; Binder and Desai, 2011) and multisensory integration (Seghier, 2012), memory (McClelland et al., 1995), and with stimulus specific regions as illustrated in Figure 1. At the processing level, if learners hear the German word Himbeer Engl. raspberry and read it, their auditory cortices will analyse and store the sounds (Dubois et al., 2013). Their left fusiform gyrus will process the letter sequence and memorize it (McCandliss et al., 2003). If the learners are additionally presented a real fruit, a multitude of stimuli will reach their brains. Smelling will engage the piriform cortex (González et al., 2006) and tasting, the anterior insula (Barros-Loscertales et al., 2012)—a gustatory area. Manipulating the raspberry and its pulp will create patterns of the texture in somatosensory regions (Sathian et al., 2011) and the motor cortex will store movement patterns necessary to grasp and hold the fruit (Hauk et al., 2004). Writing the word Himbeere and/or drawing the fruit will activate visual and motor regions (Yuan and Brown, 2015). Hence, the concept of the raspberry, and its German label Himbeere will be represented in the brain with large experience dependent sensorimotor networks (Pulvermüller and Fadiga, 2010).
# Each paragraph after web scraping:  Figure 1. Possible experience dependent word network for the German word Himbeere. Word networks reflect the experiences collected by the subject while learning. Natural learning engages a wide network comprising those regions in the brain that process the different aspects of the stimuli presented.
# Each paragraph after web scraping:  Having a particular learning style would imply that one region of the brain or network(s) selectively processes the information, i.e., more or better than another and therefore is in a way “dominant” over other regions. However, there is no scientific evidence that the brain does this. Whenever input is provided the brain processes and stores information in regions that are specifically engaged in this task. If synchronously active, brain regions wire together into functional networks (Hebb, 1949) sharing the information processed and stored. Hence, it is not surprising that smelling a rose without seeing it, allows one to imagine the color and shape of the flower (McClelland et al., 1986).
# Each paragraph after web scraping:  Most interesting for educators is the fact that the more complex brain networks are, the better they retain words (McClelland, 1985; Klimesch, 1994). A word network consisting of many components, i.e., visual, aural, kinetic, olfactory, etc. (Figure 1) stores and retrieves information more efficiently than a small network. If a component decays, for instance the sound sequence of the word, other components partially containing the lost information will restore it (Macedonia and Klimesch, 2014). This is due to the fact that all components of a network share and exchange information. Interestingly, behavioral memory research has been asserting for decades that word retention in L1 is impacted by the richness of stimuli accompanying the word (Craik and Tulving, 1975; Engelkamp and Zimmer, 1994). However, these findings have not reached L2 education and could not have an impact on procedures and methods.
# Each paragraph after web scraping:  In the early 1970s, behavioral research in L2 vocabulary learning worked on enrichment of vocabulary by means of pictures. Paivio and Csapo (1969) were among the first to recognize the power of pictures in L2 lessons. More recently, a number of empirical studies have confirmed that visual enrichment of words by means of pictures enhances memory (Curran and Doyle, 2011; Hockley and Bancroft, 2011; Bisson et al., 2014; Takashima et al., 2014). Similarly, if learners enrich L2 words with gestures, retention is enhanced in both the short and long term. Gestures engage a number of sensory modalities and the motor system, and thereby create very complex representations, i.e., word networks in the brain that highly impact retention: students learn more words and memorize words for longer than by only listening to the words and reading them (Macedonia et al., 2011; Macedonia, 2014). In a recent study, Mayer et al. (2015) compared the memory performance for words in L2 that had been learned according to three conditions: by reading only, by reading and enriching them through pictures, and by reading and performing semantically related gestures. Words that had only been read scored worst, whereas words learned with gestures scored best particularly in the long term. Results are no surprise: observing and thereafter self-performing a gesture requires more complex processing than observing a static picture. Altogether, empirical research on word learning demonstrates that enrichment of verbal information is key to word retention in L2 (Takashima et al., 2014) and to learning altogether (Shimojo and Shams, 2001; Seitz et al., 2006; Shams and Seitz, 2008; Thelen and Murray, 2013). Moreover, if one observes children while acquiring words in their L1, one will agree that they do not learn only acoustically or only visually. Instead, children collect multiple sensorimotor experiences related to words. Hence, it stands to reason that in L2 lessons “learning style specific” input, i.e., only acoustic or only visual, can by no means facilitate learning. Instead, it is possible that learning according to one's presumed learning style hinders learning.
# Each paragraph after web scraping:  If it is not a matter of learning styles matching with the teaching style of the instructor, why does performance vary so much among learners? Evidence-based research has found that subjects differ in their performance due to reasons related to their brain anatomy and function. Most interestingly, brain anatomy is not finally given at birth. Instead it changes with the use of our brains. A factor shaping brain anatomy that we encounter in classrooms is bilingualism. If a child grows up learning a second language, this induces structural changes in their white matter tracts, that is, the bilingual child's brain is wired better than that of a monolingual child (Li et al., 2014). Bilingualism also enhances cortical thickness in the inferior frontal gyrus: the core language region (Klein et al., 2014). Also, the age of L2 acquisition plays a major role: the younger the person is when they start learning L2, the larger the volume in sensory integration areas (Wei et al., 2015). In other words, in L2 classes, we find bilinguals and monolinguals and this can at least partially explain differences in learning performance. Also, phonological working memory, that is, the skill to keep unfamiliar sequences of sounds in mind, is also related to differences in word learning (Kapantzoglou et al., 2015). This has been recently demonstrated in a meta-analysis of 79 samples with around 3700 participants (Linck et al., 2014). Furthermore, two more mechanisms determine proficiency: first, cognitive control, the capacity to switch between L1 and L2 and to suppress interference from L1, a well investigated forebrain mechanism (Branzi et al., 2015), and second, attentional capacities (Bialystok, 2015). These factors that, for obvious reasons of space, here can only be mentioned are by no means connected to anything one could define as a learning style.
# Each paragraph after web scraping:  Learning style theories have not been scientifically demonstrated (Rogowsky et al., 2015), but many L2 teachers believe in them. Similarly, a multitude of L2-educators also believe that learners are right-brained or left-brained and try to improve their teaching to selectively activate the right hemisphere (Lindell, 2006; Lindell and Kidd, 2011). In both cases, we have to do with pseudoscience: It is appealing because simple, but unfortunate because as such it impacts education in a misleading way. In our time, we do have knowledge on learning processes and this knowledge should flow into L2 practice. Therefore, a basic education in cognitive neuroscience would prevent L2 teachers from becoming a soft target for pseudoscientific theories.
# Each paragraph after web scraping:  The author declares that the research was conducted in the absence of any commercial or financial relationships that could be construed as a potential conflict of interest.
# Each paragraph after web scraping:  Abutalebi, J. (2008). Neural aspects of second language representation and language control. Acta Psychol. 128, 466–478. doi: 10.1016/j.actpsy.2008.03.014
# Each paragraph after web scraping:  CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Barros-Loscertales, A., Gonzalez, J., Pulvermüller, F., Ventura-Campos, N., Bustamante, J. C., Costumero, V., et al. (2012). Reading salt activates gustatory brain regions: fMRI evidence for semantic grounding in a novel sensory modality. Cereb. Cortex 22, 2554–2563. doi: 10.1093/cercor/bhr324
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Bialystok, E. (2015). Bilingualism and the development of executive function: the role of attention. Child Dev. Perspect. 9, 117–121. doi: 10.1111/cdep.12116
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Binder, J. R., Desai, R., Graves, W., and Conant, L. (2009). Where is the semantic system? A critical review and meta-analysis of 120 functional neuroimaging studies. Cereb. Cortex 19, 2767–2796. doi: 10.1093/cercor/bhp055
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Binder, J. R., and Desai, R. H. (2011). The neurobiology of semantic memory. Trends Cogn. Sci. 15, 527–536. doi: 10.1016/j.tics.2011.10.001
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Bisson, M. J., van Heuven, W. J. B., Conklin, K., and Tunney, R. J. (2014). The role of verbal and pictorial information in multimodal incidental acquisition of foreign language vocabulary. Q. J. Exp. Psychol. 68, 1306–1326. doi: 10.1080/17470218.2014.979211
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Branzi, F. M., Della Rosa, P. A., Canini, M., Costa, A., and Abutalebi, J. (2015). Language control in bilinguals: monitoring and response selection. Cereb. Cortex. doi: 10.1093/cercor/bhv052. [Epub ahead of print].
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Craik, F. I., and Tulving, E. (1975). Depth of processing and the retention of words in episodic memory. J. Exp. Psychol. Gen. 104, 268–294. doi: 10.1037/0096-3445.104.3.268
# Each paragraph after web scraping:  CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Curran, T., and Doyle, J. (2011). Picture superiority doubly dissociates the ERP correlates of recollection and familiarity. J. Cogn. Neurosci. 23, 1247–1262. doi: 10.1162/jocn.2010.21464
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Dubois, M., Poeppel, D., and Pelli, D. G. (2013). Seeing and hearing a word: combining eye and ear is more efficient than combining the parts of a word. PLoS ONE 8:e64803. doi: 10.1371/journal.pone.0064803
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Engelkamp, J., and Zimmer, H. D. (1994). Human Memory: A Multimodal Approach. Seattle, WA: Hogrefe and Huber.
# Each paragraph after web scraping:  Fleming, N. D. (2001). Teaching and Learning Styles: VARK Strategies. Christchurch: N. Fleming.
# Each paragraph after web scraping:  Friederici, A. D. (2011). The brain basis of language processing: from structure to function. Physiol. Rev. 91, 1357–1392. doi: 10.1152/physrev.00006.2011
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  González, J., Barros-Loscertales, A., Pulvermüller, F., Meseguer, V., Sanjuán, A., Belloch, V., et al. (2006). Reading cinnamon activates olfactory brain regions. NeuroImage 32, 906–912. doi: 10.1016/j.neuroimage.2006.03.037
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Hauk, O., Johnsrude, I., and Pulvermüller, F. (2004). Somatotopic representation of action words in human motor and premotor cortex. Neuron 41, 301–307. doi: 10.1016/S0896-6273(03)00838-9
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Hebb, D. O. (1949). The Organization of Behavior. A Neuropsychological Theory. NewYork, NY; London: John Wiley and Sons; Chapman and Hall.
# Each paragraph after web scraping:  Google Scholar
# Each paragraph after web scraping:  Hockley, W. E., and Bancroft, T. (2011). Extensions of the picture superiority effect in associative recognition. Can. J. Exp. Psychol. 65, 236–244. doi: 10.1037/a0023796
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Kaminska, P. M. (2014). Learning Styles and Second Language Education. Newcastle upon Tyne: Cambridge Scholars Publishing.
# Each paragraph after web scraping:  Google Scholar
# Each paragraph after web scraping:  Kapantzoglou, M., Restrepo, M. A., Gray, S., and Thompson, M. S. (2015). Language ability in bilingual children: a latent profile analysis. J. Speech. Lang. Hear. Res. 58, 1549–1562. doi: 10.1044/2015_JSLHR-L-14-0290
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Klein, D., Mok, K., Chen, J.-K., and Watkins, K. E. (2014). Age of language learning shapes brain structure: a cortical thickness study of bilingual and monolingual individuals. Brain Lang. 131, 20–24. doi: 10.1016/j.bandl.2013.05.014
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Klimesch, W. (1994). The Structure of Long-Term Memory: A Connectivity Model of Semantic Processing. Hillsdale, NJ: Erlbaum.
# Each paragraph after web scraping:  Google Scholar
# Each paragraph after web scraping:  Li, P., Legault, J., and Litcofsky, K. A. (2014). Neuroplasticity as a function of second language learning: anatomical changes in the human brain. Cortex 58, 301–324. doi: 10.1016/j.cortex.2014.05.001
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Linck, J., Osthus, P., Koeth, J., and Bunting, M. (2014). Working memory and second language comprehension and production: a meta-analysis. Psychon. Bull. Rev. 21, 861–883. doi: 10.3758/s13423-013-0565-2
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Lindell, A. (2006). In your right mind: right hemisphere contributions to language processing and production. Neuropsychol. Rev. 16, 131–148. doi: 10.1007/s11065-006-9011-9
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Lindell, A. K., and Kidd, E. (2011). Why right-brain teaching is half-witted: a critique of the misapplication of neuroscience to education. Mind Brain Educ. 5, 121–127. doi: 10.1111/j.1751-228X.2011.01120.x
# Each paragraph after web scraping:  CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Macedonia, M. (2014). Bringing back the body into the mind: gestures enhance word learning in foreign language. Front. Psychol. 5:1467. doi: 10.3389/fpsyg.2014.01467
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Macedonia, M., and Klimesch, W. (2014). Long-term effects of gestures on memory for foreign language words trained in the classroom. Mind Brain Educ. 8, 74–88. doi: 10.1111/mbe.12047
# Each paragraph after web scraping:  CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Macedonia, M., Müller, K., and Friederici, A. D. (2011). The impact of iconic gestures on foreign language word learning and its neural substrate. Hum. Brain Mapp. 32, 982–998. doi: 10.1002/hbm.21084
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Mayer, K. M., Yildiz, I. B., Macedonia, M., and Von Kriegstein, K. (2015). Visual and motor cortices differentially support the translation of foreign language words. Curr. Biol. 25, 530–535. doi: 10.1016/j.cub.2014.11.068
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  McCandliss, B. D., Cohen, L., and Dehaene, S. (2003). The visual word form area: expertise for reading in the fusiform gyrus. Trends Cogn. Sci. 7, 293–299. doi: 10.1016/S1364-6613(03)00134-7
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  McClelland, J. L. (1985). Distributed models of cognitive processes. Applications to learning and memory. Ann. N.Y. Acad. Sci. 444, 1–9. doi: 10.1111/j.1749-6632.1985.tb37576.x
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  McClelland, J. L., McNaughton, B. L., and O'reilly, R. C. (1995). Why there are complementary learning systems in the hippocampus and neocortex: insights from the successes and failures of connectionist models of learning and memory. Psychol. Rev. 102, 419–457. doi: 10.1037/0033-295X.102.3.419
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  McClelland, J. L., Rumelhart, D. E., and Hinton, G. E. (1986). “The appeal of parallel distributed processing,” in Parallel Distributed Processing: Explorations in the Microstructure of Cognition, eds D. E. Rumelhart, J. L. McClelland, and P.R. Group (Cambridge, MA: MIT Press), 3–44.
# Each paragraph after web scraping:  Paivio, A., and Csapo, K. (1969). Concrete image and verbal memory codes. J. Exp. Psychol. 80, 279. doi: 10.1037/h0027273
# Each paragraph after web scraping:  CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Pashler, H., McDaniel, M., Rohrer, D., and Bjork, R. (2008). Learning styles: concepts and evidence. Psychol. Sci. Public Interest 9, 105–119. doi: 10.1111/j.1539-6053.2009.01038.x
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Paulhus, D. L., and Vazire, S. (2007). “The self-report method,” in Handbook of Research Methods in Personality Psychology, eds R. W. Robins, R. C. Fraley, and R. Krueger (New York, NY: Guilford), 224–239.
# Each paragraph after web scraping:  Pulvermüller, F., and Fadiga, L. (2010). Active perception: sensorimotor circuits as a cortical basis for language. Nat. Rev. Neurosci. 11, 351–360. doi: 10.1038/nrn2811
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Rogowsky, B. A., Calhoun, B. M., and Tallal, P. (2015). Matching learning style to instructional method: effects on comprehension. J. Educ. Psychol. 107, 64–78. doi: 10.1037/a0037478
# Each paragraph after web scraping:  CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Romanelli, F., Bird, E., and Ryan, M. (2009). Learning styles: a review of theory, application, and best practices. Am. J. Pharm. Educ. 73, 09. doi: 10.5688/aj730109
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Sathian, K., Lacey, S., Stilla, R., Gibson, G. O., Deshpande, G., Hu, X., et al. (2011). Dual pathways for haptic and visual perception of spatial and texture information. NeuroImage 57, 462–475. doi: 10.1016/j.neuroimage.2011.05.001
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Seghier, M. L. (2012). The angular gyrus: multiple functions and multiple subdivisions. Neuroscientist 19, 43–61. doi: 10.1177/1073858412440596
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Seitz, A. R., Kim, R., and Shams, L. (2006). Sound facilitates visual learning. Curr. Biol. 16, 1422–1427. doi: 10.1016/j.cub.2006.05.048
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Shams, L., and Seitz, A. R. (2008). Benefits of multisensory learning. Trends Cogn. Sci. 12, 411–417. doi: 10.1016/j.tics.2008.07.006
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Shimojo, S., and Shams, L. (2001). Sensory modalities are not separate modalities: plasticity and interactions. Curr. Opin. Neurobiol. 11, 505–509. doi: 10.1016/S0959-4388(00)00241-5
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Takashima, A., Bakker, I., van Hell, J. G., Janzen, G., and McQueen, J. M. (2014). Richness of information about novel words influences how episodic and semantic memory networks interact during lexicalization. NeuroImage 84, 265–278. doi: 10.1016/j.neuroimage.2013.08.023
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Thelen, A., and Murray, M. M. (2013). The efficacy of single-trial multisensory memories. Multisens. Res. 26, 483–502. doi: 10.1163/22134808-00002426
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Vazire, S., and Solomon, B. C. (2015). “Self and other knowledge of personality,” in APA Handbook of Personality and Social Psychology, Vol. 4: Personality Processes and Individual Differences. APA Handbooks in Psychology, eds M. Mikulincer, P. R. Shaver, M. L. Cooper, and R. J. Larsen (Washington, DC: American Psychological Association), 261–281.
# Each paragraph after web scraping:  Wei, M., Joshi, A. A., Zhang, M., Mei, L., Manis, F. R., He, Q., et al. (2015). How age of acquisition influences brain architecture in bilinguals. J. Neurolinguist. 36, 35–55. doi: 10.1016/j.jneuroling.2015.05.001
# Each paragraph after web scraping:  CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Yuan, Y., and Brown, S. (2015). Drawing and writing: an ALE meta-analysis of sensorimotor activations. Brain Cogn. 98, 15–26. doi: 10.1016/j.bandc.2015.05.004
# Each paragraph after web scraping:  PubMed Abstract | CrossRef Full Text | Google Scholar
# Each paragraph after web scraping:  Keywords: learning style, language learning, vocabulary acquisition, brain, sensorimotor learning, second language acquisition, embodiment and grounded cognition
# Each paragraph after web scraping:  Citation: Macedonia M (2015) Learning Styles and Vocabulary Acquisition in Second Language: How the Brain Learns. Front. Psychol. 6:1800. doi: 10.3389/fpsyg.2015.01800
# Each paragraph after web scraping:  Received: 18 August 2015; Accepted: 09 November 2015; Published: 25 November 2015.
# Each paragraph after web scraping:  Edited by:
# Each paragraph after web scraping:  Reviewed by:
# Each paragraph after web scraping:  Copyright © 2015 Macedonia. This is an open-access article distributed under the terms of the Creative Commons Attribution License (CC BY). The use, distribution or reproduction in other forums is permitted, provided the original author(s) or licensor are credited and that the original publication in this journal is cited, in accordance with accepted academic practice. No use, distribution or reproduction is permitted which does not comply with these terms.
# Each paragraph after web scraping:  *Correspondence: Manuela Macedonia, manuela@macedonia.at
# Each paragraph after web scraping:  Suggest a Research Topic >

# %%
paragraphs = soup.find_all('p')

for parts in paragraphs:
    text = parts.get_text().strip()
    fd = nltk.FreqDist(text)
    if len(text) > 0:
        print("The most common words in each paragraph:" , fd.most_common(10))
# Out:
# The most common words in each paragraph: [(' ', 8), ('c', 4), ('t', 4), ('o', 4), ('a', 3), ('r', 3), ('e', 3), ('m', 2), ('p', 2), ('2', 2)]
# The most common words in each paragraph: [('a', 4), ('i', 3), ('r', 3), (' ', 3), ('n', 2), ('v', 2), ('U', 1), ('e', 1), ('s', 1), ('t', 1)]
# The most common words in each paragraph: [('n', 5), ('e', 4), ('i', 3), ('r', 3), (' ', 3), ('s', 2), ('t', 2), ('o', 2), ('U', 1), ('v', 1)]
# The most common words in each paragraph: [(' ', 24), ('e', 20), ('t', 14), ('i', 13), ('r', 12), ('o', 10), ('a', 10), ('h', 6), ('n', 6), ('s', 6)]
# The most common words in each paragraph: [(' ', 4), ('e', 3), ('g', 2), ('s', 2), ('a', 2), ('c', 2), ('S', 1), ('u', 1), ('t', 1), ('R', 1)]
# The most common words in each paragraph: [(' ', 4), ('e', 3), ('g', 2), ('s', 2), ('a', 2), ('c', 2), ('S', 1), ('u', 1), ('t', 1), ('R', 1)]
# The most common words in each paragraph: [(' ', 185), ('e', 132), ('t', 93), ('i', 90), ('n', 86), ('a', 80), ('s', 72), ('o', 67), ('r', 65), ('l', 59)]
# The most common words in each paragraph: [(' ', 479), ('e', 329), ('t', 238), ('a', 221), ('i', 199), ('n', 189), ('s', 185), ('o', 170), ('r', 169), ('l', 138)]
# The most common words in each paragraph: [(' ', 262), ('e', 164), ('r', 116), ('i', 114), ('t', 112), ('a', 112), ('n', 104), ('s', 83), ('l', 81), ('o', 72)]
# The most common words in each paragraph: [('e', 46), (' ', 43), ('r', 22), ('t', 21), ('n', 19), ('i', 17), ('s', 15), ('o', 14), ('a', 10), ('l', 9)]
# The most common words in each paragraph: [(' ', 109), ('e', 71), ('i', 52), ('n', 51), ('t', 50), ('o', 47), ('r', 44), ('a', 38), ('s', 38), ('h', 24)]
# The most common words in each paragraph: [(' ', 139), ('e', 83), ('t', 65), ('n', 64), ('o', 58), ('a', 57), ('i', 50), ('r', 48), ('s', 41), ('c', 33)]
# The most common words in each paragraph: [(' ', 337), ('e', 213), ('r', 148), ('n', 147), ('a', 133), ('t', 127), ('o', 122), ('i', 114), ('s', 106), ('l', 78)]
# The most common words in each paragraph: [(' ', 296), ('e', 159), ('n', 136), ('a', 135), ('t', 125), ('i', 121), ('s', 101), ('o', 95), ('r', 95), ('l', 72)]
# The most common words in each paragraph: [(' ', 112), ('e', 85), ('i', 51), ('t', 50), ('a', 44), ('n', 40), ('o', 38), ('s', 35), ('r', 32), ('l', 27)]
# The most common words in each paragraph: [(' ', 26), ('e', 17), ('a', 15), ('t', 15), ('c', 12), ('o', 11), ('n', 11), ('r', 9), ('s', 9), ('i', 9)]
# The most common words in each paragraph: [(' ', 17), ('a', 11), ('.', 10), ('e', 9), ('0', 8), ('t', 7), ('o', 7), ('n', 7), ('l', 6), ('s', 6)]
# The most common words in each paragraph: [(' ', 5), ('o', 4), ('l', 4), ('e', 3), ('r', 2), ('s', 2), ('C', 1), ('R', 1), ('f', 1), ('F', 1)]
# The most common words in each paragraph: [(' ', 37), ('e', 22), ('r', 18), ('a', 17), ('o', 16), ('t', 14), ('s', 13), (',', 13), ('.', 13), ('n', 13)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 20), ('e', 14), ('1', 13), ('t', 10), ('i', 9), ('o', 8), ('.', 8), ('n', 7), ('l', 6), ('d', 5)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 31), ('e', 17), ('i', 13), ('a', 12), ('n', 11), ('r', 10), ('.', 10), ('s', 10), ('t', 9), (',', 8)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 19), ('.', 14), ('1', 10), ('i', 7), ('e', 7), ('0', 7), ('o', 7), ('n', 6), ('d', 4), ('r', 4)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 37), ('.', 18), ('n', 17), ('i', 15), ('o', 14), ('a', 13), ('l', 10), ('1', 10), ('e', 9), (',', 8)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 30), ('n', 14), ('.', 14), ('a', 13), ('i', 12), ('e', 12), ('o', 12), ('r', 9), (',', 9), ('l', 7)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 25), ('.', 14), ('o', 9), ('i', 8), ('n', 8), ('e', 8), ('0', 6), ('r', 5), ('d', 5), ('1', 5)]
# The most common words in each paragraph: [(' ', 5), ('o', 4), ('l', 4), ('e', 3), ('r', 2), ('s', 2), ('C', 1), ('R', 1), ('f', 1), ('F', 1)]
# The most common words in each paragraph: [(' ', 23), ('o', 12), ('.', 11), ('i', 11), ('r', 10), ('e', 10), ('1', 9), ('2', 8), ('a', 7), ('c', 7)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 32), ('e', 15), ('n', 13), ('o', 12), ('i', 12), ('.', 10), ('a', 10), ('r', 7), ('d', 6), ('0', 6)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 16), ('e', 8), ('a', 7), ('m', 6), ('.', 6), ('r', 5), ('n', 4), ('l', 4), (',', 4), ('H', 4)]
# The most common words in each paragraph: [(' ', 12), ('e', 7), ('i', 6), ('n', 6), ('.', 6), ('g', 5), ('a', 4), ('h', 4), ('r', 4), ('t', 4)]
# The most common words in each paragraph: [(' ', 19), ('.', 10), ('1', 10), ('i', 9), ('r', 8), ('e', 8), ('0', 7), ('s', 7), ('o', 7), ('n', 5)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 25), ('e', 17), ('.', 15), (',', 13), ('a', 12), ('o', 11), ('r', 11), ('n', 10), ('l', 9), ('0', 9)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 23), ('o', 15), ('r', 11), ('0', 10), ('n', 9), ('e', 9), ('t', 8), ('a', 7), ('.', 7), (',', 6)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 20), ('o', 12), ('a', 9), ('n', 9), ('e', 7), ('.', 6), ('h', 6), ('r', 5), ('i', 5), ('l', 5)]
# The most common words in each paragraph: [('o', 3), ('l', 2), ('G', 1), ('g', 1), ('e', 1), (' ', 1), ('S', 1), ('c', 1), ('h', 1), ('a', 1)]
# The most common words in each paragraph: [(' ', 23), ('.', 11), ('o', 10), ('i', 10), ('e', 9), ('n', 8), ('t', 8), ('c', 7), ('a', 6), ('s', 6)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 15), ('a', 10), ('n', 10), ('e', 8), ('i', 6), ('s', 5), ('.', 5), ('g', 5), ('l', 4), ('d', 4)]
# The most common words in each paragraph: [('o', 3), ('l', 2), ('G', 1), ('g', 1), ('e', 1), (' ', 1), ('S', 1), ('c', 1), ('h', 1), ('a', 1)]
# The most common words in each paragraph: [(' ', 29), ('.', 15), ('a', 14), ('n', 10), ('e', 10), ('i', 9), ('l', 8), (',', 8), ('o', 7), ('1', 7)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 32), ('n', 17), ('a', 16), ('.', 15), ('i', 14), ('l', 10), ('e', 8), (',', 8), ('s', 8), ('1', 8)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 16), ('e', 10), ('o', 7), ('l', 6), ('i', 6), ('r', 6), ('m', 5), ('c', 5), ('t', 5), ('n', 5)]
# The most common words in each paragraph: [('o', 3), ('l', 2), ('G', 1), ('g', 1), ('e', 1), (' ', 1), ('S', 1), ('c', 1), ('h', 1), ('a', 1)]
# The most common words in each paragraph: [(' ', 27), ('a', 14), ('.', 12), ('n', 12), ('i', 10), ('e', 9), ('t', 9), ('o', 9), ('0', 8), ('c', 7)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 26), ('n', 14), ('.', 11), ('o', 10), ('a', 9), (',', 8), ('s', 8), ('e', 8), ('i', 7), ('d', 6)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 20), ('i', 10), ('o', 10), ('1', 10), ('n', 9), ('0', 9), ('e', 8), ('r', 8), ('.', 7), ('t', 6)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 27), ('i', 17), ('1', 16), ('.', 12), ('n', 10), ('d', 9), ('e', 9), ('a', 9), ('t', 9), ('2', 7)]
# The most common words in each paragraph: [(' ', 5), ('o', 4), ('l', 4), ('e', 3), ('r', 2), ('s', 2), ('C', 1), ('R', 1), ('f', 1), ('F', 1)]
# The most common words in each paragraph: [(' ', 21), ('n', 13), ('e', 10), ('i', 9), ('.', 9), ('o', 8), ('g', 8), ('a', 7), ('r', 6), ('d', 5)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 26), ('e', 13), ('o', 11), ('n', 10), ('r', 9), ('a', 8), ('i', 8), ('.', 8), ('d', 7), ('s', 7)]
# The most common words in each paragraph: [(' ', 5), ('o', 4), ('l', 4), ('e', 3), ('r', 2), ('s', 2), ('C', 1), ('R', 1), ('f', 1), ('F', 1)]
# The most common words in each paragraph: [(' ', 29), ('a', 12), ('e', 12), ('i', 12), ('n', 11), ('.', 11), ('r', 10), ('o', 7), ('d', 6), (',', 6)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 30), ('.', 16), ('i', 13), ('o', 12), ('a', 11), ('r', 11), ('e', 10), ('n', 10), (',', 8), ('t', 8)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 27), ('e', 12), ('.', 10), ('r', 9), ('n', 8), ('i', 8), ('a', 7), ('s', 7), ('o', 7), ('0', 7)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 21), ('.', 16), ('1', 9), ('i', 9), ('e', 8), ('n', 8), ('o', 8), ('c', 6), ('l', 6), ('d', 6)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 40), ('e', 21), ('n', 17), ('.', 15), ('o', 14), ('s', 14), ('a', 12), ('l', 11), ('i', 11), ('c', 10)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 41), ('e', 17), ('l', 16), ('r', 15), ('a', 14), ('.', 14), ('i', 14), ('n', 13), ('t', 12), (',', 11)]
# The most common words in each paragraph: [(' ', 18), ('.', 9), ('o', 7), ('a', 6), ('e', 6), ('0', 5), ('i', 4), (',', 4), ('d', 4), ('7', 4)]
# The most common words in each paragraph: [(' ', 5), ('o', 4), ('l', 4), ('e', 3), ('r', 2), ('s', 2), ('C', 1), ('R', 1), ('f', 1), ('F', 1)]
# The most common words in each paragraph: [(' ', 22), ('.', 14), ('e', 11), ('1', 10), ('0', 9), (',', 8), ('n', 8), ('c', 7), ('s', 6), ('r', 6)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 32), ('e', 14), ('o', 12), ('.', 10), ('r', 10), (',', 9), ('a', 8), ('s', 8), ('n', 7), ('d', 7)]
# The most common words in each paragraph: [(' ', 22), ('r', 10), ('a', 10), ('i', 10), ('e', 9), ('.', 9), ('1', 8), ('o', 8), ('c', 7), ('s', 7)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 25), ('.', 12), ('o', 11), ('n', 10), ('a', 8), ('l', 8), ('t', 7), ('e', 7), ('s', 6), (',', 6)]
# The most common words in each paragraph: [(' ', 5), ('o', 4), ('l', 4), ('e', 3), ('r', 2), ('s', 2), ('C', 1), ('R', 1), ('f', 1), ('F', 1)]
# The most common words in each paragraph: [(' ', 25), ('a', 11), ('.', 11), ('e', 8), ('i', 8), (',', 8), ('n', 7), ('r', 6), ('0', 6), ('o', 5)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 32), ('a', 18), ('.', 16), (',', 13), ('e', 12), ('i', 11), ('t', 10), ('n', 9), ('o', 9), ('1', 8)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 16), ('i', 10), ('1', 8), ('e', 7), ('u', 7), ('s', 7), ('.', 6), ('n', 6), ('l', 5), ('t', 5)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 18), ('.', 14), ('i', 8), ('0', 8), (',', 6), ('a', 6), ('1', 6), ('2', 5), ('n', 4), ('6', 4)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 17), ('.', 13), ('0', 9), ('n', 7), ('i', 7), ('1', 7), ('s', 6), ('e', 6), (',', 4), ('t', 4)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 21), ('i', 12), ('0', 11), ('o', 10), ('a', 10), ('.', 9), ('e', 8), ('t', 8), ('n', 7), ('s', 7)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 35), ('e', 19), ('n', 18), ('a', 16), ('i', 15), ('.', 15), ('o', 14), (',', 10), ('r', 9), ('s', 8)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 18), ('e', 10), ('.', 9), ('0', 8), ('2', 7), ('i', 7), ('s', 7), ('l', 5), ('n', 5), ('r', 5)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [(' ', 50), ('o', 28), ('n', 22), ('a', 19), ('e', 19), ('i', 17), ('s', 16), ('.', 14), ('l', 14), ('r', 12)]
# The most common words in each paragraph: [(' ', 31), ('.', 19), ('i', 17), (',', 13), ('e', 11), ('n', 11), ('a', 8), ('o', 7), ('0', 7), ('u', 7)]
# The most common words in each paragraph: [(' ', 5), ('o', 4), ('l', 4), ('e', 3), ('r', 2), ('s', 2), ('C', 1), ('R', 1), ('f', 1), ('F', 1)]
# The most common words in each paragraph: [(' ', 20), ('n', 13), ('a', 12), ('.', 11), ('i', 9), ('o', 8), ('0', 7), ('r', 6), ('1', 6), ('t', 5)]
# The most common words in each paragraph: [(' ', 8), ('e', 4), ('o', 4), ('l', 4), ('s', 3), ('t', 3), ('r', 3), ('u', 2), ('b', 2), ('a', 2)]
# The most common words in each paragraph: [('n', 18), (' ', 16), ('i', 14), ('a', 13), ('e', 12), ('o', 12), ('r', 9), ('g', 9), ('s', 7), ('l', 7)]
# The most common words in each paragraph: [(' ', 20), ('n', 12), ('a', 11), ('i', 10), ('o', 9), ('0', 8), ('e', 7), ('.', 7), ('t', 6), ('c', 5)]
# The most common words in each paragraph: [(' ', 11), ('e', 10), ('1', 4), ('2', 4), ('0', 4), ('5', 4), ('c', 3), ('v', 3), ('d', 3), (':', 3)]
# The most common words in each paragraph: [('d', 2), ('E', 1), ('i', 1), ('t', 1), ('e', 1), (' ', 1), ('b', 1), ('y', 1), (':', 1)]
# The most common words in each paragraph: [('e', 3), ('R', 1), ('v', 1), ('i', 1), ('w', 1), ('d', 1), (' ', 1), ('b', 1), ('y', 1), (':', 1)]
# The most common words in each paragraph: [(' ', 68), ('i', 43), ('e', 40), ('t', 38), ('r', 31), ('o', 30), ('c', 22), ('n', 22), ('s', 22), ('a', 20)]
# The most common words in each paragraph: [('a', 9), ('e', 7), ('n', 6), ('o', 4), ('d', 3), ('c', 3), (' ', 3), ('r', 2), ('M', 2), ('u', 2)]
# The most common words in each paragraph: [(' ', 4), ('e', 3), ('g', 2), ('s', 2), ('a', 2), ('c', 2), ('S', 1), ('u', 1), ('t', 1), ('R', 1)]

# %%
paragraphs = soup.find_all('p')

for parts in paragraphs:
    text = parts.get_text().strip()
    if len(text) > 0:
        tokens = nltk.word_tokenize(text)
        tagged = nltk.pos_tag(tokens)
        print("POS-tagged paragraph: ", tagged)
# Out:
# POS-tagged paragraph:  [('Impact', 'NNP'), ('Factor', 'NNP'), ('2.067', 'CD'), ('|', 'NNP'), ('CiteScore', 'NNP'), ('3.2More', 'CD'), ('on', 'IN'), ('impact', 'NN'), ('›', 'NN')]
# POS-tagged paragraph:  [('University', 'NNP'), ('of', 'IN'), ('Navarra', 'NNP'), (',', ','), ('Spain', 'NNP')]
# POS-tagged paragraph:  [('University', 'NNP'), ('of', 'IN'), ('Groningen', 'NNP'), (',', ','), ('Netherlands', 'NNP')]
# POS-tagged paragraph:  [('The', 'DT'), ('editor', 'NN'), ('and', 'CC'), ('reviewers', 'NNS'), ("'", 'POS'), ('affiliations', 'NNS'), ('are', 'VBP'), ('the', 'DT'), ('latest', 'JJS'), ('provided', 'VBN'), ('on', 'IN'), ('their', 'PRP$'), ('Loop', 'NNP'), ('research', 'NN'), ('profiles', 'NNS'), ('and', 'CC'), ('may', 'MD'), ('not', 'RB'), ('reflect', 'VB'), ('their', 'PRP$'), ('situation', 'NN'), ('at', 'IN'), ('the', 'DT'), ('time', 'NN'), ('of', 'IN'), ('review', 'NN'), ('.', '.')]
# POS-tagged paragraph:  [('Suggest', 'NNP'), ('a', 'DT'), ('Research', 'NNP'), ('Topic', 'NNP'), ('>', 'VBD')]
# POS-tagged paragraph:  [('Suggest', 'NNP'), ('a', 'DT'), ('Research', 'NNP'), ('Topic', 'NNP'), ('>', 'VBD')]
# POS-tagged paragraph:  [('In', 'IN'), ('recent', 'JJ'), ('years', 'NNS'), (',', ','), ('foreign', 'JJ'), ('language', 'NN'), ('education', 'NN'), ('has', 'VBZ'), ('been', 'VBN'), ('focussing', 'VBG'), ('on', 'IN'), ('learning', 'VBG'), ('styles', 'NNS'), ('.', '.'), ('However', 'RB'), (',', ','), ('despite', 'IN'), ('the', 'DT'), ('quantity', 'NN'), ('of', 'IN'), ('articles', 'NNS'), ('and', 'CC'), ('practice', 'NN'), ('books', 'NNS'), (',', ','), ('websites', 'VBZ'), ('on', 'IN'), ('the', 'DT'), ('topic', 'NN'), (',', ','), ('and', 'CC'), ('investment', 'NN'), ('in', 'IN'), ('teacher', 'NN'), ('training', 'NN'), (',', ','), ('there', 'EX'), ('is', 'VBZ'), ('no', 'DT'), ('empirical', 'JJ'), ('evidence', 'NN'), ('for', 'IN'), ('the', 'DT'), ('existence', 'NN'), ('of', 'IN'), ('learning', 'VBG'), ('styles', 'NNS'), ('.', '.'), ('Furthermore', 'RB'), (',', ','), ('if', 'IN'), ('one', 'CD'), ('agrees', 'VBZ'), ('that', 'IN'), ('it', 'PRP'), ('is', 'VBZ'), ('the', 'DT'), ('brain', 'NN'), ('that', 'IN'), ('learns', 'VBZ'), (',', ','), ('there', 'EX'), ('should', 'MD'), ('be', 'VB'), ('indicators', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('brain', 'NN'), ('for', 'IN'), ('the', 'DT'), ('existence', 'NN'), ('of', 'IN'), ('learning', 'VBG'), ('styles', 'NNS'), (',', ','), ('anatomically', 'RB'), (',', ','), ('and/or', 'VBZ'), ('functionally', 'RB'), ('.', '.'), ('This', 'DT'), ('is', 'VBZ'), ('not', 'RB'), ('the', 'DT'), ('case', 'NN'), ('.', '.'), ('In', 'IN'), ('this', 'DT'), ('paper', 'NN'), (',', ','), ('the', 'DT'), ('validity', 'NN'), ('and', 'CC'), ('reliability', 'NN'), ('of', 'IN'), ('tests', 'NNS'), ('assessing', 'VBG'), ('learning', 'NN'), ('styles', 'NNS'), ('are', 'VBP'), ('questioned', 'VBN'), ('.', '.'), ('Thereafter', 'NNP'), (',', ','), ('following', 'VBG'), ('on', 'IN'), ('basics', 'NNS'), ('of', 'IN'), ('cognitive', 'JJ'), ('neuroscience', 'NN'), ('and', 'CC'), ('experimental', 'JJ'), ('evidence', 'NN'), ('it', 'PRP'), ('is', 'VBZ'), ('argued', 'VBN'), ('that', 'IN'), ('the', 'DT'), ('natural', 'JJ'), ('way', 'NN'), ('for', 'IN'), ('the', 'DT'), ('brain', 'NN'), ('to', 'TO'), ('learn', 'VB'), ('words', 'NNS'), ('is', 'VBZ'), ('by', 'IN'), ('collecting', 'VBG'), ('multiple', 'JJ'), ('sensory', 'NN'), ('and', 'CC'), ('sensorimotor', 'NN'), ('experiences', 'NNS'), ('.', '.'), ('In', 'IN'), ('fact', 'NN'), (',', ','), ('evidence-based', 'JJ'), ('literature', 'NN'), ('in', 'IN'), ('the', 'DT'), ('domain', 'NN'), ('of', 'IN'), ('vocabulary', 'JJ'), ('acquisition', 'NN'), ('demonstrates', 'VBZ'), ('that', 'IN'), ('the', 'DT'), ('inclusion', 'NN'), ('of', 'IN'), ('multiple', 'JJ'), ('modalities', 'NNS'), ('leads', 'VBZ'), ('to', 'TO'), ('best', 'VB'), ('results', 'NNS'), ('.', '.'), ('Impoverished', 'NNP'), ('linguistic', 'JJ'), ('input', 'NN'), ('by', 'IN'), ('allowing', 'VBG'), ('only', 'RB'), ('one', 'CD'), ('modality', 'NN'), (',', ','), ('for', 'IN'), ('example', 'NN'), ('only', 'RB'), ('acoustic', 'JJ'), ('or', 'CC'), ('visual', 'JJ'), ('input—the', 'NN'), ('so', 'RB'), ('called', 'VBD'), ('learning', 'JJ'), ('style', 'NN'), ('(', '('), ('Pashler', 'NNP'), ('et', 'RB'), ('al.', 'RB'), (',', ','), ('2008', 'CD'), (')', ')'), ('of', 'IN'), ('the', 'DT'), ('student—reduces', 'NNS'), ('the', 'DT'), ('chances', 'NNS'), ('of', 'IN'), ('acquiring', 'VBG'), ('words', 'NNS'), ('.', '.'), ('Also', 'RB'), (',', ','), ('the', 'DT'), ('article', 'NN'), ('briefly', 'NN'), ('outlines', 'NNS'), ('brain', 'NN'), ('related', 'JJ'), ('factors', 'NNS'), ('that', 'WDT'), ('lead', 'VBP'), ('to', 'TO'), ('high', 'JJ'), ('performance', 'NN'), ('in', 'IN'), ('vocabulary', 'JJ'), ('learning', 'NN'), ('.', '.')]
# POS-tagged paragraph:  [('A', 'DT'), ('closer', 'JJR'), ('look', 'NN'), ('at', 'IN'), ('the', 'DT'), ('literature', 'NN'), ('on', 'IN'), ('learning', 'NN'), ('styles', 'NNS'), ('shows', 'VBZ'), ('a', 'DT'), ('multitude', 'NN'), ('of', 'IN'), ('models', 'NNS'), ('that', 'IN'), ('classify', 'VBP'), ('learners', 'NNS'), ('in', 'IN'), ('different', 'JJ'), ('types', 'NNS'), ('.', '.'), ('Despite', 'IN'), ('differences', 'NNS'), ('(', '('), ('for', 'IN'), ('reviews', 'NNS'), ('see', 'VBP'), ('Pashler', 'NNP'), ('et', 'FW'), ('al.', 'NN'), (',', ','), ('2008', 'CD'), (';', ':'), ('Romanelli', 'NNP'), ('et', 'FW'), ('al.', 'NN'), (',', ','), ('2009', 'CD'), (';', ':'), ('Kaminska', 'NNP'), (',', ','), ('2014', 'CD'), (')', ')'), (',', ','), ('learning', 'VBG'), ('style', 'NN'), ('models', 'NNS'), ('have', 'VBP'), ('a', 'DT'), ('common', 'JJ'), ('base', 'NN'), (':', ':'), ('they', 'PRP'), ('sustain', 'VBP'), ('that', 'IN'), ('not', 'RB'), ('all', 'DT'), ('individuals', 'NNS'), ('learn', 'VBP'), ('the', 'DT'), ('same', 'JJ'), ('way', 'NN'), ('.', '.'), ('One', 'CD'), ('of', 'IN'), ('them', 'PRP'), (',', ','), ('the', 'DT'), ('VARK', 'NNP'), ('model', 'NN'), ('(', '('), ('Fleming', 'NNP'), (',', ','), ('2001', 'CD'), (')', ')'), (',', ','), ('categorizes', 'VBZ'), ('learners', 'NNS'), ('as', 'IN'), ('aural', 'JJ'), (',', ','), ('visual', 'JJ'), (',', ','), ('kinaesthetic', 'JJ'), (',', ','), ('haptic', 'JJ'), (',', ','), ('and', 'CC'), ('learners', 'NNS'), ('who', 'WP'), ('prefer', 'VBP'), ('to', 'TO'), ('read', 'VB'), ('and', 'CC'), ('write', 'VB'), ('.', '.'), ('In', 'IN'), ('second', 'JJ'), ('language', 'NN'), ('instruction', 'NN'), (',', ','), ('this', 'DT'), ('view', 'NN'), ('implicates', 'VBZ'), ('that', 'IN'), ('a', 'DT'), ('person', 'NN'), ('classified', 'VBN'), ('as', 'IN'), ('aural', 'JJ'), ('should', 'MD'), ('learn', 'VB'), ('vocabulary', 'JJ'), ('items', 'NNS'), ('by', 'IN'), ('means', 'NNS'), ('of', 'IN'), ('acoustic', 'JJ'), ('training', 'NN'), (',', ','), ('whereas', 'IN'), ('a', 'DT'), ('visual', 'JJ'), ('learner', 'NN'), ('would', 'MD'), ('optimize', 'VB'), ('the', 'DT'), ('learning', 'NN'), ('outcome', 'NN'), ('by', 'IN'), ('reading', 'VBG'), ('and/or', 'NN'), ('using', 'VBG'), ('flash', 'JJ'), ('cards', 'NNS'), ('that', 'WDT'), ('illustrate', 'VBP'), ('the', 'DT'), ('word', 'NN'), ("'s", 'POS'), ('semantics', 'NNS'), ('.', '.'), ('However', 'RB'), (',', ','), ('despite', 'IN'), ('being', 'VBG'), ('very', 'RB'), ('popular', 'JJ'), (',', ','), ('this', 'DT'), ('position', 'NN'), ('is', 'VBZ'), ('not', 'RB'), ('evidence-based', 'JJ'), ('.', '.'), ('It', 'PRP'), ('is', 'VBZ'), ('simply', 'RB'), ('taken', 'VBN'), ('for', 'IN'), ('granted', 'VBN'), ('with', 'IN'), ('the', 'DT'), ('intention', 'NN'), ('to', 'TO'), ('promote', 'VB'), ('the', 'DT'), ('learners', 'NNS'), ("'", 'POS'), ('capacities', 'NNS'), ('.', '.'), ('Also', 'RB'), (',', ','), ('it', 'PRP'), ('is', 'VBZ'), ('not', 'RB'), ('proven', 'JJ'), ('that', 'IN'), ('assessments', 'NNS'), ('administered', 'VBN'), ('to', 'TO'), ('determine', 'VB'), ('the', 'DT'), ('learning', 'NN'), ('style', 'NN'), ('to', 'TO'), ('which', 'WDT'), ('a', 'DT'), ('person', 'NN'), ('belongs', 'NNS'), ('are', 'VBP'), ('valid', 'JJ'), ('and', 'CC'), ('reliable', 'JJ'), ('.', '.'), ('Nobody', 'NN'), ('has', 'VBZ'), ('proven', 'VBN'), ('that', 'IN'), ('they', 'PRP'), ('measure', 'VBP'), ('what', 'WP'), ('they', 'PRP'), ('claim', 'VBP'), ('.', '.'), ('One', 'CD'), ('major', 'JJ'), ('issue', 'NN'), ('connected', 'VBN'), ('to', 'TO'), ('these', 'DT'), ('tests', 'NNS'), ('is', 'VBZ'), ('that', 'IN'), ('they', 'PRP'), ('are', 'VBP'), ('based', 'VBN'), ('on', 'IN'), ('self-report', 'NN'), ('.', '.'), ('It', 'PRP'), ('has', 'VBZ'), ('been', 'VBN'), ('suggested', 'VBN'), ('that', 'IN'), ('in', 'IN'), ('self-reports', 'NNS'), (',', ','), ('subjects', 'NNS'), ('might', 'MD'), ('lack', 'VB'), ('introspection', 'NN'), ('and', 'CC'), ('that', 'IN'), ('yes', 'NNS'), ('or', 'CC'), ('no', 'DT'), ('answers', 'N ...
# POS-tagged paragraph:  [('Considering', 'VBG'), ('that', 'IN'), ('it', 'PRP'), ('is', 'VBZ'), ('the', 'DT'), ('brain', 'NN'), ('that', 'IN'), ('learns', 'VBZ'), (',', ','), ('it', 'PRP'), ('is', 'VBZ'), ('worth', 'JJ'), ('asking', 'VBG'), ('what', 'WP'), ('happens', 'VBZ'), ('at', 'IN'), ('this', 'DT'), ('level', 'NN'), ('during', 'IN'), ('word', 'NN'), ('learning', 'NN'), ('in', 'IN'), ('L2', 'NNP'), ('.', '.'), ('On', 'IN'), ('average', 'NN'), (',', ','), ('if', 'IN'), ('learners', 'NNS'), ('display', 'VBP'), ('no', 'DT'), ('congenital', 'NN'), ('or', 'CC'), ('acquired', 'VBD'), ('neurological', 'JJ'), ('impairments', 'NNS'), (',', ','), ('they', 'PRP'), ('should', 'MD'), ('possess', 'VB'), ('similar', 'JJ'), ('learning', 'NN'), ('potentials', 'NNS'), ('.', '.'), ('Billions', 'NNS'), ('of', 'IN'), ('neurons', 'NNS'), ('process', 'NN'), ('and', 'CC'), ('store', 'VB'), ('the', 'DT'), ('incoming', 'JJ'), ('information', 'NN'), ('in', 'IN'), ('large', 'JJ'), ('networks', 'NNS'), ('.', '.'), ('They', 'PRP'), ('include', 'VBP'), ('areas', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('brain', 'NN'), ('that', 'WDT'), ('deal', 'NN'), ('with', 'IN'), ('language', 'NN'), ('(', '('), ('Friederici', 'NNP'), (',', ','), ('2011', 'CD'), (')', ')'), (',', ','), ('cognitive', 'JJ'), ('control', 'NN'), ('(', '('), ('Abutalebi', 'NNP'), (',', ','), ('2008', 'CD'), (')', ')'), (',', ','), ('semantic', 'JJ'), ('processing', 'NN'), ('(', '('), ('Binder', 'NNP'), ('et', 'VBZ'), ('al.', 'RB'), (',', ','), ('2009', 'CD'), (';', ':'), ('Binder', 'NNP'), ('and', 'CC'), ('Desai', 'NNP'), (',', ','), ('2011', 'CD'), (')', ')'), ('and', 'CC'), ('multisensory', 'JJ'), ('integration', 'NN'), ('(', '('), ('Seghier', 'NNP'), (',', ','), ('2012', 'CD'), (')', ')'), (',', ','), ('memory', 'NN'), ('(', '('), ('McClelland', 'NNP'), ('et', 'RB'), ('al.', 'RB'), (',', ','), ('1995', 'CD'), (')', ')'), (',', ','), ('and', 'CC'), ('with', 'IN'), ('stimulus', 'JJ'), ('specific', 'JJ'), ('regions', 'NNS'), ('as', 'IN'), ('illustrated', 'VBN'), ('in', 'IN'), ('Figure', 'NNP'), ('1', 'CD'), ('.', '.'), ('At', 'IN'), ('the', 'DT'), ('processing', 'NN'), ('level', 'NN'), (',', ','), ('if', 'IN'), ('learners', 'NNS'), ('hear', 'VBP'), ('the', 'DT'), ('German', 'JJ'), ('word', 'NN'), ('Himbeer', 'NNP'), ('Engl', 'NNP'), ('.', '.'), ('raspberry', 'NN'), ('and', 'CC'), ('read', 'VB'), ('it', 'PRP'), (',', ','), ('their', 'PRP$'), ('auditory', 'JJ'), ('cortices', 'NNS'), ('will', 'MD'), ('analyse', 'VB'), ('and', 'CC'), ('store', 'VB'), ('the', 'DT'), ('sounds', 'NNS'), ('(', '('), ('Dubois', 'NNP'), ('et', 'RB'), ('al.', 'RB'), (',', ','), ('2013', 'CD'), (')', ')'), ('.', '.'), ('Their', 'PRP$'), ('left', 'JJ'), ('fusiform', 'NN'), ('gyrus', 'NN'), ('will', 'MD'), ('process', 'VB'), ('the', 'DT'), ('letter', 'NN'), ('sequence', 'NN'), ('and', 'CC'), ('memorize', 'VB'), ('it', 'PRP'), ('(', '('), ('McCandliss', 'NNP'), ('et', 'RB'), ('al.', 'RB'), (',', ','), ('2003', 'CD'), (')', ')'), ('.', '.'), ('If', 'IN'), ('the', 'DT'), ('learners', 'NNS'), ('are', 'VBP'), ('additionally', 'RB'), ('presented', 'VBN'), ('a', 'DT'), ('real', 'JJ'), ('fruit', 'NN'), (',', ','), ('a', 'DT'), ('multitude', 'NN'), ('of', 'IN'), ('stimuli', 'NNS'), ('will', 'MD'), ('reach', 'VB'), ('their', 'PRP$'), ('brains', 'NNS'), ('.', '.'), ('Smelling', 'VBG'), ('will', 'MD'), ('engage', 'VB'), ('the', 'DT'), ('piriform', 'NN'), ('cortex', 'NN'), ('(', '('), ('González', 'NNP'), ('et', 'RB'), ('al.', 'RB'), (',', ','), ('2006', 'CD'), (')', ')'), ('and', 'CC'), ('tasting', 'VBG'), (',', ','), ('the', 'DT'), ('anterior', 'JJ'), ('insula', 'NN'), ('(', '('), ('Barros-Loscertales', 'NNP'), ('et', 'FW'), ('al.', 'NN'), (',', ','), ('2012', 'CD'), (')', ')'), ('—a', 'FW'), ('gustatory', 'JJ'), ('area', 'NN'), ('.', '.'), ('Manipulating', 'VBG'), ('the', 'DT'), ('raspberry', 'NN'), ('and', 'CC'), ('its', 'PRP$'), ('pulp', 'NN'), ('will', 'MD'), ('create', 'VB'), ('patterns', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('te ...
# POS-tagged paragraph:  [('Figure', 'NN'), ('1', 'CD'), ('.', '.'), ('Possible', 'JJ'), ('experience', 'NN'), ('dependent', 'NN'), ('word', 'NN'), ('network', 'NN'), ('for', 'IN'), ('the', 'DT'), ('German', 'JJ'), ('word', 'NN'), ('Himbeere', 'NNP'), ('.', '.'), ('Word', 'NNP'), ('networks', 'VBZ'), ('reflect', 'VBP'), ('the', 'DT'), ('experiences', 'NNS'), ('collected', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('subject', 'NN'), ('while', 'IN'), ('learning', 'VBG'), ('.', '.'), ('Natural', 'NNP'), ('learning', 'VBG'), ('engages', 'VBZ'), ('a', 'DT'), ('wide', 'JJ'), ('network', 'NN'), ('comprising', 'VBG'), ('those', 'DT'), ('regions', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('brain', 'NN'), ('that', 'WDT'), ('process', 'VBP'), ('the', 'DT'), ('different', 'JJ'), ('aspects', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('stimuli', 'NN'), ('presented', 'VBD'), ('.', '.')]
# POS-tagged paragraph:  [('Having', 'VBG'), ('a', 'DT'), ('particular', 'JJ'), ('learning', 'NN'), ('style', 'NN'), ('would', 'MD'), ('imply', 'VB'), ('that', 'IN'), ('one', 'CD'), ('region', 'NN'), ('of', 'IN'), ('the', 'DT'), ('brain', 'NN'), ('or', 'CC'), ('network', 'NN'), ('(', '('), ('s', 'NN'), (')', ')'), ('selectively', 'RB'), ('processes', 'VBZ'), ('the', 'DT'), ('information', 'NN'), (',', ','), ('i.e.', 'NN'), (',', ','), ('more', 'RBR'), ('or', 'CC'), ('better', 'JJR'), ('than', 'IN'), ('another', 'DT'), ('and', 'CC'), ('therefore', 'NN'), ('is', 'VBZ'), ('in', 'IN'), ('a', 'DT'), ('way', 'NN'), ('“', 'JJ'), ('dominant', 'JJ'), ('”', 'NN'), ('over', 'IN'), ('other', 'JJ'), ('regions', 'NNS'), ('.', '.'), ('However', 'RB'), (',', ','), ('there', 'EX'), ('is', 'VBZ'), ('no', 'DT'), ('scientific', 'JJ'), ('evidence', 'NN'), ('that', 'IN'), ('the', 'DT'), ('brain', 'NN'), ('does', 'VBZ'), ('this', 'DT'), ('.', '.'), ('Whenever', 'WRB'), ('input', 'NN'), ('is', 'VBZ'), ('provided', 'VBN'), ('the', 'DT'), ('brain', 'NN'), ('processes', 'NNS'), ('and', 'CC'), ('stores', 'NNS'), ('information', 'NN'), ('in', 'IN'), ('regions', 'NNS'), ('that', 'WDT'), ('are', 'VBP'), ('specifically', 'RB'), ('engaged', 'VBN'), ('in', 'IN'), ('this', 'DT'), ('task', 'NN'), ('.', '.'), ('If', 'IN'), ('synchronously', 'RB'), ('active', 'JJ'), (',', ','), ('brain', 'NN'), ('regions', 'NNS'), ('wire', 'VBP'), ('together', 'RB'), ('into', 'IN'), ('functional', 'JJ'), ('networks', 'NNS'), ('(', '('), ('Hebb', 'NNP'), (',', ','), ('1949', 'CD'), (')', ')'), ('sharing', 'VBG'), ('the', 'DT'), ('information', 'NN'), ('processed', 'VBD'), ('and', 'CC'), ('stored', 'VBD'), ('.', '.'), ('Hence', 'NNP'), (',', ','), ('it', 'PRP'), ('is', 'VBZ'), ('not', 'RB'), ('surprising', 'JJ'), ('that', 'IN'), ('smelling', 'VBG'), ('a', 'DT'), ('rose', 'VBD'), ('without', 'IN'), ('seeing', 'VBG'), ('it', 'PRP'), (',', ','), ('allows', 'VBZ'), ('one', 'CD'), ('to', 'TO'), ('imagine', 'VB'), ('the', 'DT'), ('color', 'NN'), ('and', 'CC'), ('shape', 'NN'), ('of', 'IN'), ('the', 'DT'), ('flower', 'NN'), ('(', '('), ('McClelland', 'NNP'), ('et', 'RB'), ('al.', 'RB'), (',', ','), ('1986', 'CD'), (')', ')'), ('.', '.')]
# POS-tagged paragraph:  [('Most', 'JJS'), ('interesting', 'JJ'), ('for', 'IN'), ('educators', 'NNS'), ('is', 'VBZ'), ('the', 'DT'), ('fact', 'NN'), ('that', 'IN'), ('the', 'DT'), ('more', 'RBR'), ('complex', 'JJ'), ('brain', 'NN'), ('networks', 'NNS'), ('are', 'VBP'), (',', ','), ('the', 'DT'), ('better', 'JJR'), ('they', 'PRP'), ('retain', 'VBP'), ('words', 'NNS'), ('(', '('), ('McClelland', 'NNP'), (',', ','), ('1985', 'CD'), (';', ':'), ('Klimesch', 'NNP'), (',', ','), ('1994', 'CD'), (')', ')'), ('.', '.'), ('A', 'DT'), ('word', 'NN'), ('network', 'NN'), ('consisting', 'VBG'), ('of', 'IN'), ('many', 'JJ'), ('components', 'NNS'), (',', ','), ('i.e.', 'FW'), (',', ','), ('visual', 'JJ'), (',', ','), ('aural', 'JJ'), (',', ','), ('kinetic', 'JJ'), (',', ','), ('olfactory', 'JJ'), (',', ','), ('etc', 'FW'), ('.', '.'), ('(', '('), ('Figure', 'NNP'), ('1', 'CD'), (')', ')'), ('stores', 'NNS'), ('and', 'CC'), ('retrieves', 'NNS'), ('information', 'NN'), ('more', 'RBR'), ('efficiently', 'RB'), ('than', 'IN'), ('a', 'DT'), ('small', 'JJ'), ('network', 'NN'), ('.', '.'), ('If', 'IN'), ('a', 'DT'), ('component', 'NN'), ('decays', 'NN'), (',', ','), ('for', 'IN'), ('instance', 'NN'), ('the', 'DT'), ('sound', 'JJ'), ('sequence', 'NN'), ('of', 'IN'), ('the', 'DT'), ('word', 'NN'), (',', ','), ('other', 'JJ'), ('components', 'NNS'), ('partially', 'RB'), ('containing', 'VBG'), ('the', 'DT'), ('lost', 'VBN'), ('information', 'NN'), ('will', 'MD'), ('restore', 'VB'), ('it', 'PRP'), ('(', '('), ('Macedonia', 'NNP'), ('and', 'CC'), ('Klimesch', 'NNP'), (',', ','), ('2014', 'CD'), (')', ')'), ('.', '.'), ('This', 'DT'), ('is', 'VBZ'), ('due', 'JJ'), ('to', 'TO'), ('the', 'DT'), ('fact', 'NN'), ('that', 'IN'), ('all', 'DT'), ('components', 'NNS'), ('of', 'IN'), ('a', 'DT'), ('network', 'NN'), ('share', 'NN'), ('and', 'CC'), ('exchange', 'NN'), ('information', 'NN'), ('.', '.'), ('Interestingly', 'NNP'), (',', ','), ('behavioral', 'JJ'), ('memory', 'NN'), ('research', 'NN'), ('has', 'VBZ'), ('been', 'VBN'), ('asserting', 'VBG'), ('for', 'IN'), ('decades', 'NNS'), ('that', 'IN'), ('word', 'NN'), ('retention', 'NN'), ('in', 'IN'), ('L1', 'NNP'), ('is', 'VBZ'), ('impacted', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('richness', 'NN'), ('of', 'IN'), ('stimuli', 'NNS'), ('accompanying', 'VBG'), ('the', 'DT'), ('word', 'NN'), ('(', '('), ('Craik', 'NNP'), ('and', 'CC'), ('Tulving', 'NNP'), (',', ','), ('1975', 'CD'), (';', ':'), ('Engelkamp', 'NNP'), ('and', 'CC'), ('Zimmer', 'NNP'), (',', ','), ('1994', 'CD'), (')', ')'), ('.', '.'), ('However', 'RB'), (',', ','), ('these', 'DT'), ('findings', 'NNS'), ('have', 'VBP'), ('not', 'RB'), ('reached', 'VBN'), ('L2', 'NNP'), ('education', 'NN'), ('and', 'CC'), ('could', 'MD'), ('not', 'RB'), ('have', 'VB'), ('an', 'DT'), ('impact', 'NN'), ('on', 'IN'), ('procedures', 'NNS'), ('and', 'CC'), ('methods', 'NNS'), ('.', '.')]
# POS-tagged paragraph:  [('In', 'IN'), ('the', 'DT'), ('early', 'JJ'), ('1970s', 'CD'), (',', ','), ('behavioral', 'JJ'), ('research', 'NN'), ('in', 'IN'), ('L2', 'NNP'), ('vocabulary', 'JJ'), ('learning', 'NN'), ('worked', 'VBN'), ('on', 'IN'), ('enrichment', 'NN'), ('of', 'IN'), ('vocabulary', 'JJ'), ('by', 'IN'), ('means', 'NNS'), ('of', 'IN'), ('pictures', 'NNS'), ('.', '.'), ('Paivio', 'NNP'), ('and', 'CC'), ('Csapo', 'NNP'), ('(', '('), ('1969', 'CD'), (')', ')'), ('were', 'VBD'), ('among', 'IN'), ('the', 'DT'), ('first', 'JJ'), ('to', 'TO'), ('recognize', 'VB'), ('the', 'DT'), ('power', 'NN'), ('of', 'IN'), ('pictures', 'NNS'), ('in', 'IN'), ('L2', 'NNP'), ('lessons', 'NNS'), ('.', '.'), ('More', 'RBR'), ('recently', 'RB'), (',', ','), ('a', 'DT'), ('number', 'NN'), ('of', 'IN'), ('empirical', 'JJ'), ('studies', 'NNS'), ('have', 'VBP'), ('confirmed', 'VBN'), ('that', 'IN'), ('visual', 'JJ'), ('enrichment', 'NN'), ('of', 'IN'), ('words', 'NNS'), ('by', 'IN'), ('means', 'NNS'), ('of', 'IN'), ('pictures', 'NNS'), ('enhances', 'NNS'), ('memory', 'NN'), ('(', '('), ('Curran', 'NNP'), ('and', 'CC'), ('Doyle', 'NNP'), (',', ','), ('2011', 'CD'), (';', ':'), ('Hockley', 'NNP'), ('and', 'CC'), ('Bancroft', 'NNP'), (',', ','), ('2011', 'CD'), (';', ':'), ('Bisson', 'NNP'), ('et', 'FW'), ('al.', 'NN'), (',', ','), ('2014', 'CD'), (';', ':'), ('Takashima', 'NNP'), ('et', 'FW'), ('al.', 'NN'), (',', ','), ('2014', 'CD'), (')', ')'), ('.', '.'), ('Similarly', 'RB'), (',', ','), ('if', 'IN'), ('learners', 'NNS'), ('enrich', 'VBP'), ('L2', 'NNP'), ('words', 'NNS'), ('with', 'IN'), ('gestures', 'NNS'), (',', ','), ('retention', 'NN'), ('is', 'VBZ'), ('enhanced', 'VBN'), ('in', 'IN'), ('both', 'CC'), ('the', 'DT'), ('short', 'JJ'), ('and', 'CC'), ('long', 'JJ'), ('term', 'NN'), ('.', '.'), ('Gestures', 'VBZ'), ('engage', 'VB'), ('a', 'DT'), ('number', 'NN'), ('of', 'IN'), ('sensory', 'JJ'), ('modalities', 'NNS'), ('and', 'CC'), ('the', 'DT'), ('motor', 'NN'), ('system', 'NN'), (',', ','), ('and', 'CC'), ('thereby', 'RB'), ('create', 'VB'), ('very', 'RB'), ('complex', 'JJ'), ('representations', 'NNS'), (',', ','), ('i.e.', 'FW'), (',', ','), ('word', 'NN'), ('networks', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('brain', 'NN'), ('that', 'WDT'), ('highly', 'RB'), ('impact', 'JJ'), ('retention', 'NN'), (':', ':'), ('students', 'NNS'), ('learn', 'VBP'), ('more', 'JJR'), ('words', 'NNS'), ('and', 'CC'), ('memorize', 'VB'), ('words', 'NNS'), ('for', 'IN'), ('longer', 'JJR'), ('than', 'IN'), ('by', 'IN'), ('only', 'JJ'), ('listening', 'VBG'), ('to', 'TO'), ('the', 'DT'), ('words', 'NNS'), ('and', 'CC'), ('reading', 'VBG'), ('them', 'PRP'), ('(', '('), ('Macedonia', 'NNP'), ('et', 'RB'), ('al.', 'RB'), (',', ','), ('2011', 'CD'), (';', ':'), ('Macedonia', 'NNP'), (',', ','), ('2014', 'CD'), (')', ')'), ('.', '.'), ('In', 'IN'), ('a', 'DT'), ('recent', 'JJ'), ('study', 'NN'), (',', ','), ('Mayer', 'NNP'), ('et', 'FW'), ('al', 'NN'), ('.', '.'), ('(', '('), ('2015', 'CD'), (')', ')'), ('compared', 'VBN'), ('the', 'DT'), ('memory', 'NN'), ('performance', 'NN'), ('for', 'IN'), ('words', 'NNS'), ('in', 'IN'), ('L2', 'NNP'), ('that', 'WDT'), ('had', 'VBD'), ('been', 'VBN'), ('learned', 'VBN'), ('according', 'VBG'), ('to', 'TO'), ('three', 'CD'), ('conditions', 'NNS'), (':', ':'), ('by', 'IN'), ('reading', 'VBG'), ('only', 'RB'), (',', ','), ('by', 'IN'), ('reading', 'VBG'), ('and', 'CC'), ('enriching', 'VBG'), ('them', 'PRP'), ('through', 'IN'), ('pictures', 'NNS'), (',', ','), ('and', 'CC'), ('by', 'IN'), ('reading', 'VBG'), ('and', 'CC'), ('performing', 'VBG'), ('semantically', 'RB'), ('related', 'JJ'), ('gestures', 'NNS'), ('.', '.'), ('Words', 'NNS'), ('that', 'WDT'), ('had', 'VBD'), ('only', 'RB'), ('been', 'VBN'), ('read', 'VBN'), ('scored', 'VBN'), ('worst', 'JJS'), (',', ','), ('whereas', 'JJ'), ('words', 'NNS'), ('learned', 'VBN'), ('with', 'IN'), ('gestures', 'NNS'), ('scored', 'VBN'), ('best', 'JJS'), ('particularly', 'RB'), ('in', 'IN'), ('the', ...
# POS-tagged paragraph:  [('If', 'IN'), ('it', 'PRP'), ('is', 'VBZ'), ('not', 'RB'), ('a', 'DT'), ('matter', 'NN'), ('of', 'IN'), ('learning', 'VBG'), ('styles', 'NNS'), ('matching', 'VBG'), ('with', 'IN'), ('the', 'DT'), ('teaching', 'VBG'), ('style', 'NN'), ('of', 'IN'), ('the', 'DT'), ('instructor', 'NN'), (',', ','), ('why', 'WRB'), ('does', 'VBZ'), ('performance', 'NN'), ('vary', 'NN'), ('so', 'RB'), ('much', 'JJ'), ('among', 'IN'), ('learners', 'NNS'), ('?', '.'), ('Evidence-based', 'JJ'), ('research', 'NN'), ('has', 'VBZ'), ('found', 'VBN'), ('that', 'IN'), ('subjects', 'NNS'), ('differ', 'VBP'), ('in', 'IN'), ('their', 'PRP$'), ('performance', 'NN'), ('due', 'JJ'), ('to', 'TO'), ('reasons', 'NNS'), ('related', 'VBN'), ('to', 'TO'), ('their', 'PRP$'), ('brain', 'NN'), ('anatomy', 'NN'), ('and', 'CC'), ('function', 'NN'), ('.', '.'), ('Most', 'JJS'), ('interestingly', 'RB'), (',', ','), ('brain', 'NN'), ('anatomy', 'NN'), ('is', 'VBZ'), ('not', 'RB'), ('finally', 'RB'), ('given', 'VBN'), ('at', 'IN'), ('birth', 'NN'), ('.', '.'), ('Instead', 'RB'), ('it', 'PRP'), ('changes', 'VBZ'), ('with', 'IN'), ('the', 'DT'), ('use', 'NN'), ('of', 'IN'), ('our', 'PRP$'), ('brains', 'NNS'), ('.', '.'), ('A', 'DT'), ('factor', 'NN'), ('shaping', 'VBG'), ('brain', 'NN'), ('anatomy', 'NN'), ('that', 'IN'), ('we', 'PRP'), ('encounter', 'VBP'), ('in', 'IN'), ('classrooms', 'NNS'), ('is', 'VBZ'), ('bilingualism', 'NN'), ('.', '.'), ('If', 'IN'), ('a', 'DT'), ('child', 'NN'), ('grows', 'VBZ'), ('up', 'RP'), ('learning', 'VBG'), ('a', 'DT'), ('second', 'JJ'), ('language', 'NN'), (',', ','), ('this', 'DT'), ('induces', 'VBZ'), ('structural', 'JJ'), ('changes', 'NNS'), ('in', 'IN'), ('their', 'PRP$'), ('white', 'JJ'), ('matter', 'NN'), ('tracts', 'NNS'), (',', ','), ('that', 'DT'), ('is', 'VBZ'), (',', ','), ('the', 'DT'), ('bilingual', 'JJ'), ('child', 'NN'), ("'s", 'POS'), ('brain', 'NN'), ('is', 'VBZ'), ('wired', 'VBN'), ('better', 'JJR'), ('than', 'IN'), ('that', 'DT'), ('of', 'IN'), ('a', 'DT'), ('monolingual', 'JJ'), ('child', 'NN'), ('(', '('), ('Li', 'NNP'), ('et', 'RB'), ('al.', 'RB'), (',', ','), ('2014', 'CD'), (')', ')'), ('.', '.'), ('Bilingualism', 'NNP'), ('also', 'RB'), ('enhances', 'VBZ'), ('cortical', 'JJ'), ('thickness', 'NN'), ('in', 'IN'), ('the', 'DT'), ('inferior', 'JJ'), ('frontal', 'JJ'), ('gyrus', 'NN'), (':', ':'), ('the', 'DT'), ('core', 'NN'), ('language', 'NN'), ('region', 'NN'), ('(', '('), ('Klein', 'NNP'), ('et', 'VBZ'), ('al.', 'RB'), (',', ','), ('2014', 'CD'), (')', ')'), ('.', '.'), ('Also', 'RB'), (',', ','), ('the', 'DT'), ('age', 'NN'), ('of', 'IN'), ('L2', 'NNP'), ('acquisition', 'NN'), ('plays', 'VBZ'), ('a', 'DT'), ('major', 'JJ'), ('role', 'NN'), (':', ':'), ('the', 'DT'), ('younger', 'JJR'), ('the', 'DT'), ('person', 'NN'), ('is', 'VBZ'), ('when', 'WRB'), ('they', 'PRP'), ('start', 'VBP'), ('learning', 'VBG'), ('L2', 'NNP'), (',', ','), ('the', 'DT'), ('larger', 'JJR'), ('the', 'DT'), ('volume', 'NN'), ('in', 'IN'), ('sensory', 'JJ'), ('integration', 'NN'), ('areas', 'NNS'), ('(', '('), ('Wei', 'NNP'), ('et', 'RB'), ('al.', 'RB'), (',', ','), ('2015', 'CD'), (')', ')'), ('.', '.'), ('In', 'IN'), ('other', 'JJ'), ('words', 'NNS'), (',', ','), ('in', 'IN'), ('L2', 'NNP'), ('classes', 'NNS'), (',', ','), ('we', 'PRP'), ('find', 'VBP'), ('bilinguals', 'NNS'), ('and', 'CC'), ('monolinguals', 'NNS'), ('and', 'CC'), ('this', 'DT'), ('can', 'MD'), ('at', 'IN'), ('least', 'JJS'), ('partially', 'RB'), ('explain', 'JJ'), ('differences', 'NNS'), ('in', 'IN'), ('learning', 'VBG'), ('performance', 'NN'), ('.', '.'), ('Also', 'RB'), (',', ','), ('phonological', 'JJ'), ('working', 'VBG'), ('memory', 'NN'), (',', ','), ('that', 'WDT'), ('is', 'VBZ'), (',', ','), ('the', 'DT'), ('skill', 'NN'), ('to', 'TO'), ('keep', 'VB'), ('unfamiliar', 'JJ'), ('sequences', 'NNS'), ('of', 'IN'), ('sounds', 'NNS'), ('in', 'IN'), ('mind', 'NN'), (',', ','), ('is', 'VBZ'), ('also', 'RB'), ('related', 'VBN'), ('to', 'TO'), ('differences', ...
# POS-tagged paragraph:  [('Learning', 'VBG'), ('style', 'NN'), ('theories', 'NNS'), ('have', 'VBP'), ('not', 'RB'), ('been', 'VBN'), ('scientifically', 'RB'), ('demonstrated', 'VBN'), ('(', '('), ('Rogowsky', 'NNP'), ('et', 'FW'), ('al.', 'NN'), (',', ','), ('2015', 'CD'), (')', ')'), (',', ','), ('but', 'CC'), ('many', 'JJ'), ('L2', 'NNP'), ('teachers', 'NNS'), ('believe', 'VBP'), ('in', 'IN'), ('them', 'PRP'), ('.', '.'), ('Similarly', 'RB'), (',', ','), ('a', 'DT'), ('multitude', 'NN'), ('of', 'IN'), ('L2-educators', 'NNP'), ('also', 'RB'), ('believe', 'VBP'), ('that', 'IN'), ('learners', 'NNS'), ('are', 'VBP'), ('right-brained', 'JJ'), ('or', 'CC'), ('left-brained', 'JJ'), ('and', 'CC'), ('try', 'VB'), ('to', 'TO'), ('improve', 'VB'), ('their', 'PRP$'), ('teaching', 'NN'), ('to', 'TO'), ('selectively', 'RB'), ('activate', 'VB'), ('the', 'DT'), ('right', 'NN'), ('hemisphere', 'NN'), ('(', '('), ('Lindell', 'NNP'), (',', ','), ('2006', 'CD'), (';', ':'), ('Lindell', 'NNP'), ('and', 'CC'), ('Kidd', 'NNP'), (',', ','), ('2011', 'CD'), (')', ')'), ('.', '.'), ('In', 'IN'), ('both', 'DT'), ('cases', 'NNS'), (',', ','), ('we', 'PRP'), ('have', 'VBP'), ('to', 'TO'), ('do', 'VB'), ('with', 'IN'), ('pseudoscience', 'NN'), (':', ':'), ('It', 'PRP'), ('is', 'VBZ'), ('appealing', 'VBG'), ('because', 'RB'), ('simple', 'JJ'), (',', ','), ('but', 'CC'), ('unfortunate', 'RB'), ('because', 'IN'), ('as', 'IN'), ('such', 'JJ'), ('it', 'PRP'), ('impacts', 'VBZ'), ('education', 'NN'), ('in', 'IN'), ('a', 'DT'), ('misleading', 'JJ'), ('way', 'NN'), ('.', '.'), ('In', 'IN'), ('our', 'PRP$'), ('time', 'NN'), (',', ','), ('we', 'PRP'), ('do', 'VBP'), ('have', 'VB'), ('knowledge', 'VBN'), ('on', 'IN'), ('learning', 'NN'), ('processes', 'NNS'), ('and', 'CC'), ('this', 'DT'), ('knowledge', 'NN'), ('should', 'MD'), ('flow', 'VB'), ('into', 'IN'), ('L2', 'NNP'), ('practice', 'NN'), ('.', '.'), ('Therefore', 'RB'), (',', ','), ('a', 'DT'), ('basic', 'JJ'), ('education', 'NN'), ('in', 'IN'), ('cognitive', 'JJ'), ('neuroscience', 'NN'), ('would', 'MD'), ('prevent', 'VB'), ('L2', 'NNP'), ('teachers', 'NNS'), ('from', 'IN'), ('becoming', 'VBG'), ('a', 'DT'), ('soft', 'JJ'), ('target', 'NN'), ('for', 'IN'), ('pseudoscientific', 'JJ'), ('theories', 'NNS'), ('.', '.')]
# POS-tagged paragraph:  [('The', 'DT'), ('author', 'NN'), ('declares', 'VBZ'), ('that', 'IN'), ('the', 'DT'), ('research', 'NN'), ('was', 'VBD'), ('conducted', 'VBN'), ('in', 'IN'), ('the', 'DT'), ('absence', 'NN'), ('of', 'IN'), ('any', 'DT'), ('commercial', 'JJ'), ('or', 'CC'), ('financial', 'JJ'), ('relationships', 'NNS'), ('that', 'WDT'), ('could', 'MD'), ('be', 'VB'), ('construed', 'VBN'), ('as', 'IN'), ('a', 'DT'), ('potential', 'JJ'), ('conflict', 'NN'), ('of', 'IN'), ('interest', 'NN'), ('.', '.')]
# POS-tagged paragraph:  [('Abutalebi', 'NNP'), (',', ','), ('J', 'NNP'), ('.', '.'), ('(', '('), ('2008', 'CD'), (')', ')'), ('.', '.'), ('Neural', 'JJ'), ('aspects', 'NNS'), ('of', 'IN'), ('second', 'JJ'), ('language', 'NN'), ('representation', 'NN'), ('and', 'CC'), ('language', 'NN'), ('control', 'NN'), ('.', '.'), ('Acta', 'NNP'), ('Psychol', 'NNP'), ('.', '.'), ('128', 'CD'), (',', ','), ('466–478', 'CD'), ('.', '.'), ('doi', 'NN'), (':', ':'), ('10.1016/j.actpsy.2008.03.014', 'CD')]
# POS-tagged paragraph:  [('CrossRef', 'NNP'), ('Full', 'NNP'), ('Text', 'NNP'), ('|', 'NNP'), ('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('Barros-Loscertales', 'NNS'), (',', ','), ('A.', 'NNP'), (',', ','), ('Gonzalez', 'NNP'), (',', ','), ('J.', 'NNP'), (',', ','), ('Pulvermüller', 'NNP'), (',', ','), ('F.', 'NNP'), (',', ','), ('Ventura-Campos', 'NNP'), (',', ','), ('N.', 'NNP'), (',', ','), ('Bustamante', 'NNP'), (',', ','), ('J.', 'NNP'), ('C.', 'NNP'), (',', ','), ('Costumero', 'NNP'), (',', ','), ('V.', 'NNP'), (',', ','), ('et', 'RB'), ('al', 'NN'), ('.', '.'), ('(', '('), ('2012', 'CD'), (')', ')'), ('.', '.'), ('Reading', 'VBG'), ('salt', 'NN'), ('activates', 'NNS'), ('gustatory', 'JJ'), ('brain', 'NN'), ('regions', 'NNS'), (':', ':'), ('fMRI', 'NN'), ('evidence', 'NN'), ('for', 'IN'), ('semantic', 'JJ'), ('grounding', 'NN'), ('in', 'IN'), ('a', 'DT'), ('novel', 'JJ'), ('sensory', 'JJ'), ('modality', 'NN'), ('.', '.'), ('Cereb', 'NNP'), ('.', '.'), ('Cortex', 'NNP'), ('22', 'CD'), (',', ','), ('2554–2563', 'CD'), ('.', '.'), ('doi', 'NN'), (':', ':'), ('10.1093/cercor/bhr324', 'CD')]
# POS-tagged paragraph:  [('PubMed', 'NNP'), ('Abstract', 'NNP'), ('|', 'NNP'), ('CrossRef', 'NNP'), ('Full', 'NNP'), ('Text', 'NNP'), ('|', 'NNP'), ('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('Bialystok', 'NNP'), (',', ','), ('E.', 'NNP'), ('(', '('), ('2015', 'CD'), (')', ')'), ('.', '.'), ('Bilingualism', 'NN'), ('and', 'CC'), ('the', 'DT'), ('development', 'NN'), ('of', 'IN'), ('executive', 'JJ'), ('function', 'NN'), (':', ':'), ('the', 'DT'), ('role', 'NN'), ('of', 'IN'), ('attention', 'NN'), ('.', '.'), ('Child', 'NNP'), ('Dev', 'NNP'), ('.', '.'), ('Perspect', 'NNP'), ('.', '.'), ('9', 'CD'), (',', ','), ('117–121', 'CD'), ('.', '.'), ('doi', 'NN'), (':', ':'), ('10.1111/cdep.12116', 'CD')]
# POS-tagged paragraph:  [('PubMed', 'NNP'), ('Abstract', 'NNP'), ('|', 'NNP'), ('CrossRef', 'NNP'), ('Full', 'NNP'), ('Text', 'NNP'), ('|', 'NNP'), ('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('Binder', 'NNP'), (',', ','), ('J.', 'NNP'), ('R.', 'NNP'), (',', ','), ('Desai', 'NNP'), (',', ','), ('R.', 'NNP'), (',', ','), ('Graves', 'NNP'), (',', ','), ('W.', 'NNP'), (',', ','), ('and', 'CC'), ('Conant', 'NNP'), (',', ','), ('L.', 'NNP'), ('(', '('), ('2009', 'CD'), (')', ')'), ('.', '.'), ('Where', 'WRB'), ('is', 'VBZ'), ('the', 'DT'), ('semantic', 'JJ'), ('system', 'NN'), ('?', '.'), ('A', 'DT'), ('critical', 'JJ'), ('review', 'NN'), ('and', 'CC'), ('meta-analysis', 'NN'), ('of', 'IN'), ('120', 'CD'), ('functional', 'JJ'), ('neuroimaging', 'NN'), ('studies', 'NNS'), ('.', '.'), ('Cereb', 'NNP'), ('.', '.'), ('Cortex', 'NNP'), ('19', 'CD'), (',', ','), ('2767–2796', 'CD'), ('.', '.'), ('doi', 'NN'), (':', ':'), ('10.1093/cercor/bhp055', 'CD')]
# POS-tagged paragraph:  [('PubMed', 'NNP'), ('Abstract', 'NNP'), ('|', 'NNP'), ('CrossRef', 'NNP'), ('Full', 'NNP'), ('Text', 'NNP'), ('|', 'NNP'), ('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('Binder', 'NNP'), (',', ','), ('J.', 'NNP'), ('R.', 'NNP'), (',', ','), ('and', 'CC'), ('Desai', 'NNP'), (',', ','), ('R.', 'NNP'), ('H.', 'NNP'), ('(', '('), ('2011', 'CD'), (')', ')'), ('.', '.'), ('The', 'DT'), ('neurobiology', 'NN'), ('of', 'IN'), ('semantic', 'JJ'), ('memory', 'NN'), ('.', '.'), ('Trends', 'VBZ'), ('Cogn', 'NNP'), ('.', '.'), ('Sci', 'NNP'), ('.', '.'), ('15', 'CD'), (',', ','), ('527–536', 'CD'), ('.', '.'), ('doi', 'NN'), (':', ':'), ('10.1016/j.tics.2011.10.001', 'CD')]
# POS-tagged paragraph:  [('PubMed', 'NNP'), ('Abstract', 'NNP'), ('|', 'NNP'), ('CrossRef', 'NNP'), ('Full', 'NNP'), ('Text', 'NNP'), ('|', 'NNP'), ('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('Bisson', 'NNP'), (',', ','), ('M.', 'NNP'), ('J.', 'NNP'), (',', ','), ('van', 'NN'), ('Heuven', 'NNP'), (',', ','), ('W.', 'NNP'), ('J', 'NNP'), ('.', '.'), ('B.', 'NNP'), (',', ','), ('Conklin', 'NNP'), (',', ','), ('K.', 'NNP'), (',', ','), ('and', 'CC'), ('Tunney', 'NNP'), (',', ','), ('R.', 'NNP'), ('J', 'NNP'), ('.', '.'), ('(', '('), ('2014', 'CD'), (')', ')'), ('.', '.'), ('The', 'DT'), ('role', 'NN'), ('of', 'IN'), ('verbal', 'JJ'), ('and', 'CC'), ('pictorial', 'JJ'), ('information', 'NN'), ('in', 'IN'), ('multimodal', 'JJ'), ('incidental', 'JJ'), ('acquisition', 'NN'), ('of', 'IN'), ('foreign', 'JJ'), ('language', 'NN'), ('vocabulary', 'JJ'), ('.', '.'), ('Q.', 'NNP'), ('J.', 'NNP'), ('Exp', 'NNP'), ('.', '.'), ('Psychol', 'NNP'), ('.', '.'), ('68', 'CD'), (',', ','), ('1306–1326', 'CD'), ('.', '.'), ('doi', 'NN'), (':', ':'), ('10.1080/17470218.2014.979211', 'CD')]
# POS-tagged paragraph:  [('PubMed', 'NNP'), ('Abstract', 'NNP'), ('|', 'NNP'), ('CrossRef', 'NNP'), ('Full', 'NNP'), ('Text', 'NNP'), ('|', 'NNP'), ('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('Branzi', 'NNP'), (',', ','), ('F.', 'NNP'), ('M.', 'NNP'), (',', ','), ('Della', 'NNP'), ('Rosa', 'NNP'), (',', ','), ('P.', 'NNP'), ('A.', 'NN'), (',', ','), ('Canini', 'NNP'), (',', ','), ('M.', 'NNP'), (',', ','), ('Costa', 'NNP'), (',', ','), ('A.', 'NNP'), (',', ','), ('and', 'CC'), ('Abutalebi', 'NNP'), (',', ','), ('J', 'NNP'), ('.', '.'), ('(', '('), ('2015', 'CD'), (')', ')'), ('.', '.'), ('Language', 'VB'), ('control', 'NN'), ('in', 'IN'), ('bilinguals', 'NNS'), (':', ':'), ('monitoring', 'NN'), ('and', 'CC'), ('response', 'NN'), ('selection', 'NN'), ('.', '.'), ('Cereb', 'NNP'), ('.', '.'), ('Cortex', 'NNP'), ('.', '.'), ('doi', 'NN'), (':', ':'), ('10.1093/cercor/bhv052', 'CD'), ('.', '.'), ('[', 'VB'), ('Epub', 'NNP'), ('ahead', 'RB'), ('of', 'IN'), ('print', 'NN'), (']', 'NN'), ('.', '.')]
# POS-tagged paragraph:  [('PubMed', 'NNP'), ('Abstract', 'NNP'), ('|', 'NNP'), ('CrossRef', 'NNP'), ('Full', 'NNP'), ('Text', 'NNP'), ('|', 'NNP'), ('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('Craik', 'NNP'), (',', ','), ('F.', 'NNP'), ('I.', 'NNP'), (',', ','), ('and', 'CC'), ('Tulving', 'NNP'), (',', ','), ('E.', 'NNP'), ('(', '('), ('1975', 'CD'), (')', ')'), ('.', '.'), ('Depth', 'NNP'), ('of', 'IN'), ('processing', 'NN'), ('and', 'CC'), ('the', 'DT'), ('retention', 'NN'), ('of', 'IN'), ('words', 'NNS'), ('in', 'IN'), ('episodic', 'JJ'), ('memory', 'NN'), ('.', '.'), ('J.', 'NNP'), ('Exp', 'NNP'), ('.', '.'), ('Psychol', 'NNP'), ('.', '.'), ('Gen.', 'NNP'), ('104', 'CD'), (',', ','), ('268–294', 'CD'), ('.', '.'), ('doi', 'NN'), (':', ':'), ('10.1037/0096-3445.104.3.268', 'JJ')]
# POS-tagged paragraph:  [('CrossRef', 'NNP'), ('Full', 'NNP'), ('Text', 'NNP'), ('|', 'NNP'), ('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('Curran', 'NNP'), (',', ','), ('T.', 'NNP'), (',', ','), ('and', 'CC'), ('Doyle', 'NNP'), (',', ','), ('J', 'NNP'), ('.', '.'), ('(', '('), ('2011', 'CD'), (')', ')'), ('.', '.'), ('Picture', 'NN'), ('superiority', 'NN'), ('doubly', 'RB'), ('dissociates', 'VBZ'), ('the', 'DT'), ('ERP', 'NNP'), ('correlates', 'NNS'), ('of', 'IN'), ('recollection', 'NN'), ('and', 'CC'), ('familiarity', 'NN'), ('.', '.'), ('J.', 'NNP'), ('Cogn', 'NNP'), ('.', '.'), ('Neurosci', 'NNP'), ('.', '.'), ('23', 'CD'), (',', ','), ('1247–1262', 'CD'), ('.', '.'), ('doi', 'NN'), (':', ':'), ('10.1162/jocn.2010.21464', 'CD')]
# POS-tagged paragraph:  [('PubMed', 'NNP'), ('Abstract', 'NNP'), ('|', 'NNP'), ('CrossRef', 'NNP'), ('Full', 'NNP'), ('Text', 'NNP'), ('|', 'NNP'), ('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('Dubois', 'NNP'), (',', ','), ('M.', 'NNP'), (',', ','), ('Poeppel', 'NNP'), (',', ','), ('D.', 'NNP'), (',', ','), ('and', 'CC'), ('Pelli', 'NNP'), (',', ','), ('D.', 'NNP'), ('G.', 'NNP'), ('(', '('), ('2013', 'CD'), (')', ')'), ('.', '.'), ('Seeing', 'VBG'), ('and', 'CC'), ('hearing', 'VBG'), ('a', 'DT'), ('word', 'NN'), (':', ':'), ('combining', 'NN'), ('eye', 'NN'), ('and', 'CC'), ('ear', 'NN'), ('is', 'VBZ'), ('more', 'RBR'), ('efficient', 'JJ'), ('than', 'IN'), ('combining', 'VBG'), ('the', 'DT'), ('parts', 'NNS'), ('of', 'IN'), ('a', 'DT'), ('word', 'NN'), ('.', '.'), ('PLoS', 'NNP'), ('ONE', 'CD'), ('8', 'CD'), (':', ':'), ('e64803', 'NN'), ('.', '.'), ('doi', 'NN'), (':', ':'), ('10.1371/journal.pone.0064803', 'CD')]
# POS-tagged paragraph:  [('PubMed', 'NNP'), ('Abstract', 'NNP'), ('|', 'NNP'), ('CrossRef', 'NNP'), ('Full', 'NNP'), ('Text', 'NNP'), ('|', 'NNP'), ('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('Engelkamp', 'NNP'), (',', ','), ('J.', 'NNP'), (',', ','), ('and', 'CC'), ('Zimmer', 'NNP'), (',', ','), ('H.', 'NNP'), ('D.', 'NNP'), ('(', '('), ('1994', 'CD'), (')', ')'), ('.', '.'), ('Human', 'JJ'), ('Memory', 'NN'), (':', ':'), ('A', 'DT'), ('Multimodal', 'NNP'), ('Approach', 'NNP'), ('.', '.'), ('Seattle', 'NNP'), (',', ','), ('WA', 'NNP'), (':', ':'), ('Hogrefe', 'NNP'), ('and', 'CC'), ('Huber', 'NNP'), ('.', '.')]
# POS-tagged paragraph:  [('Fleming', 'VBG'), (',', ','), ('N.', 'NNP'), ('D.', 'NNP'), ('(', '('), ('2001', 'CD'), (')', ')'), ('.', '.'), ('Teaching', 'VBG'), ('and', 'CC'), ('Learning', 'VBG'), ('Styles', 'NNS'), (':', ':'), ('VARK', 'NNP'), ('Strategies', 'NNP'), ('.', '.'), ('Christchurch', 'NN'), (':', ':'), ('N.', 'NNP'), ('Fleming', 'NNP'), ('.', '.')]
# POS-tagged paragraph:  [('Friederici', 'NNP'), (',', ','), ('A.', 'NNP'), ('D.', 'NNP'), ('(', '('), ('2011', 'CD'), (')', ')'), ('.', '.'), ('The', 'DT'), ('brain', 'NN'), ('basis', 'NN'), ('of', 'IN'), ('language', 'NN'), ('processing', 'NN'), (':', ':'), ('from', 'IN'), ('structure', 'NN'), ('to', 'TO'), ('function', 'NN'), ('.', '.'), ('Physiol', 'NNP'), ('.', '.'), ('Rev', 'NNP'), ('.', '.'), ('91', 'CD'), (',', ','), ('1357–1392', 'CD'), ('.', '.'), ('doi', 'NN'), (':', ':'), ('10.1152/physrev.00006.2011', 'CD')]
# POS-tagged paragraph:  [('PubMed', 'NNP'), ('Abstract', 'NNP'), ('|', 'NNP'), ('CrossRef', 'NNP'), ('Full', 'NNP'), ('Text', 'NNP'), ('|', 'NNP'), ('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('González', 'NNP'), (',', ','), ('J.', 'NNP'), (',', ','), ('Barros-Loscertales', 'NNP'), (',', ','), ('A.', 'NNP'), (',', ','), ('Pulvermüller', 'NNP'), (',', ','), ('F.', 'NNP'), (',', ','), ('Meseguer', 'NNP'), (',', ','), ('V.', 'NNP'), (',', ','), ('Sanjuán', 'NNP'), (',', ','), ('A.', 'NNP'), (',', ','), ('Belloch', 'NNP'), (',', ','), ('V.', 'NNP'), (',', ','), ('et', 'RB'), ('al', 'NN'), ('.', '.'), ('(', '('), ('2006', 'CD'), (')', ')'), ('.', '.'), ('Reading', 'VBG'), ('cinnamon', 'JJ'), ('activates', 'NNS'), ('olfactory', 'JJ'), ('brain', 'NN'), ('regions', 'NNS'), ('.', '.'), ('NeuroImage', 'NN'), ('32', 'CD'), (',', ','), ('906–912', 'CD'), ('.', '.'), ('doi', 'NN'), (':', ':'), ('10.1016/j.neuroimage.2006.03.037', 'CD')]
# POS-tagged paragraph:  [('PubMed', 'NNP'), ('Abstract', 'NNP'), ('|', 'NNP'), ('CrossRef', 'NNP'), ('Full', 'NNP'), ('Text', 'NNP'), ('|', 'NNP'), ('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('Hauk', 'NNP'), (',', ','), ('O.', 'NNP'), (',', ','), ('Johnsrude', 'NNP'), (',', ','), ('I.', 'NNP'), (',', ','), ('and', 'CC'), ('Pulvermüller', 'NNP'), (',', ','), ('F.', 'NNP'), ('(', '('), ('2004', 'CD'), (')', ')'), ('.', '.'), ('Somatotopic', 'NNP'), ('representation', 'NN'), ('of', 'IN'), ('action', 'NN'), ('words', 'NNS'), ('in', 'IN'), ('human', 'JJ'), ('motor', 'NN'), ('and', 'CC'), ('premotor', 'NN'), ('cortex', 'NN'), ('.', '.'), ('Neuron', 'NNP'), ('41', 'CD'), (',', ','), ('301–307', 'CD'), ('.', '.'), ('doi', 'NN'), (':', ':'), ('10.1016/S0896-6273', 'JJ'), ('(', '('), ('03', 'CD'), (')', ')'), ('00838-9', 'NN')]
# POS-tagged paragraph:  [('PubMed', 'NNP'), ('Abstract', 'NNP'), ('|', 'NNP'), ('CrossRef', 'NNP'), ('Full', 'NNP'), ('Text', 'NNP'), ('|', 'NNP'), ('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('Hebb', 'NNP'), (',', ','), ('D.', 'NNP'), ('O', 'NNP'), ('.', '.'), ('(', '('), ('1949', 'CD'), (')', ')'), ('.', '.'), ('The', 'DT'), ('Organization', 'NNP'), ('of', 'IN'), ('Behavior', 'NNP'), ('.', '.'), ('A', 'NNP'), ('Neuropsychological', 'NNP'), ('Theory', 'NNP'), ('.', '.'), ('NewYork', 'NNP'), (',', ','), ('NY', 'NNP'), (';', ':'), ('London', 'NNP'), (':', ':'), ('John', 'NNP'), ('Wiley', 'NNP'), ('and', 'CC'), ('Sons', 'NNP'), (';', ':'), ('Chapman', 'NNP'), ('and', 'CC'), ('Hall', 'NNP'), ('.', '.')]
# POS-tagged paragraph:  [('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('Hockley', 'NNP'), (',', ','), ('W.', 'NNP'), ('E.', 'NNP'), (',', ','), ('and', 'CC'), ('Bancroft', 'NNP'), (',', ','), ('T.', 'NNP'), ('(', '('), ('2011', 'CD'), (')', ')'), ('.', '.'), ('Extensions', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('picture', 'NN'), ('superiority', 'NN'), ('effect', 'NN'), ('in', 'IN'), ('associative', 'JJ'), ('recognition', 'NN'), ('.', '.'), ('Can', 'MD'), ('.', '.'), ('J.', 'NNP'), ('Exp', 'NNP'), ('.', '.'), ('Psychol', 'NNP'), ('.', '.'), ('65', 'CD'), (',', ','), ('236–244', 'CD'), ('.', '.'), ('doi', 'NN'), (':', ':'), ('10.1037/a0023796', 'CD')]
# POS-tagged paragraph:  [('PubMed', 'NNP'), ('Abstract', 'NNP'), ('|', 'NNP'), ('CrossRef', 'NNP'), ('Full', 'NNP'), ('Text', 'NNP'), ('|', 'NNP'), ('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('Kaminska', 'NNP'), (',', ','), ('P.', 'NNP'), ('M.', 'NNP'), ('(', '('), ('2014', 'CD'), (')', ')'), ('.', '.'), ('Learning', 'VBG'), ('Styles', 'NNP'), ('and', 'CC'), ('Second', 'NNP'), ('Language', 'NNP'), ('Education', 'NNP'), ('.', '.'), ('Newcastle', 'NNP'), ('upon', 'IN'), ('Tyne', 'NNP'), (':', ':'), ('Cambridge', 'NNP'), ('Scholars', 'NNP'), ('Publishing', 'NNP'), ('.', '.')]
# POS-tagged paragraph:  [('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('Kapantzoglou', 'NNP'), (',', ','), ('M.', 'NNP'), (',', ','), ('Restrepo', 'NNP'), (',', ','), ('M.', 'NNP'), ('A.', 'NN'), (',', ','), ('Gray', 'NNP'), (',', ','), ('S.', 'NNP'), (',', ','), ('and', 'CC'), ('Thompson', 'NNP'), (',', ','), ('M.', 'NNP'), ('S.', 'NNP'), ('(', '('), ('2015', 'CD'), (')', ')'), ('.', '.'), ('Language', 'JJ'), ('ability', 'NN'), ('in', 'IN'), ('bilingual', 'JJ'), ('children', 'NNS'), (':', ':'), ('a', 'DT'), ('latent', 'NN'), ('profile', 'NN'), ('analysis', 'NN'), ('.', '.'), ('J', 'NNP'), ('.', '.'), ('Speech', 'NNP'), ('.', '.'), ('Lang', 'NNP'), ('.', '.'), ('Hear', 'NNP'), ('.', '.'), ('Res', 'NNP'), ('.', '.'), ('58', 'CD'), (',', ','), ('1549–1562', 'CD'), ('.', '.'), ('doi', 'NN'), (':', ':'), ('10.1044/2015_JSLHR-L-14-0290', 'JJ')]
# POS-tagged paragraph:  [('PubMed', 'NNP'), ('Abstract', 'NNP'), ('|', 'NNP'), ('CrossRef', 'NNP'), ('Full', 'NNP'), ('Text', 'NNP'), ('|', 'NNP'), ('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('Klein', 'NNP'), (',', ','), ('D.', 'NNP'), (',', ','), ('Mok', 'NNP'), (',', ','), ('K.', 'NNP'), (',', ','), ('Chen', 'NNP'), (',', ','), ('J.-K.', 'NNP'), (',', ','), ('and', 'CC'), ('Watkins', 'NNP'), (',', ','), ('K.', 'NNP'), ('E.', 'NNP'), ('(', '('), ('2014', 'CD'), (')', ')'), ('.', '.'), ('Age', 'NNP'), ('of', 'IN'), ('language', 'NN'), ('learning', 'VBG'), ('shapes', 'NNS'), ('brain', 'NN'), ('structure', 'NN'), (':', ':'), ('a', 'DT'), ('cortical', 'JJ'), ('thickness', 'NN'), ('study', 'NN'), ('of', 'IN'), ('bilingual', 'JJ'), ('and', 'CC'), ('monolingual', 'JJ'), ('individuals', 'NNS'), ('.', '.'), ('Brain', 'NNP'), ('Lang', 'NNP'), ('.', '.'), ('131', 'CD'), (',', ','), ('20–24', 'CD'), ('.', '.'), ('doi', 'NN'), (':', ':'), ('10.1016/j.bandl.2013.05.014', 'CD')]
# POS-tagged paragraph:  [('PubMed', 'NNP'), ('Abstract', 'NNP'), ('|', 'NNP'), ('CrossRef', 'NNP'), ('Full', 'NNP'), ('Text', 'NNP'), ('|', 'NNP'), ('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('Klimesch', 'NNP'), (',', ','), ('W.', 'NNP'), ('(', '('), ('1994', 'CD'), (')', ')'), ('.', '.'), ('The', 'DT'), ('Structure', 'NN'), ('of', 'IN'), ('Long-Term', 'JJ'), ('Memory', 'NN'), (':', ':'), ('A', 'DT'), ('Connectivity', 'NNP'), ('Model', 'NNP'), ('of', 'IN'), ('Semantic', 'NNP'), ('Processing', 'NNP'), ('.', '.'), ('Hillsdale', 'NNP'), (',', ','), ('NJ', 'NNP'), (':', ':'), ('Erlbaum', 'NN'), ('.', '.')]
# POS-tagged paragraph:  [('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('Li', 'NNP'), (',', ','), ('P.', 'NNP'), (',', ','), ('Legault', 'NNP'), (',', ','), ('J.', 'NNP'), (',', ','), ('and', 'CC'), ('Litcofsky', 'NNP'), (',', ','), ('K.', 'NNP'), ('A', 'NNP'), ('.', '.'), ('(', '('), ('2014', 'CD'), (')', ')'), ('.', '.'), ('Neuroplasticity', 'NNP'), ('as', 'IN'), ('a', 'DT'), ('function', 'NN'), ('of', 'IN'), ('second', 'JJ'), ('language', 'NN'), ('learning', 'NN'), (':', ':'), ('anatomical', 'JJ'), ('changes', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('human', 'JJ'), ('brain', 'NN'), ('.', '.'), ('Cortex', 'NNP'), ('58', 'CD'), (',', ','), ('301–324', 'CD'), ('.', '.'), ('doi', 'NN'), (':', ':'), ('10.1016/j.cortex.2014.05.001', 'CD')]
# POS-tagged paragraph:  [('PubMed', 'NNP'), ('Abstract', 'NNP'), ('|', 'NNP'), ('CrossRef', 'NNP'), ('Full', 'NNP'), ('Text', 'NNP'), ('|', 'NNP'), ('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('Linck', 'NNP'), (',', ','), ('J.', 'NNP'), (',', ','), ('Osthus', 'NNP'), (',', ','), ('P.', 'NNP'), (',', ','), ('Koeth', 'NNP'), (',', ','), ('J.', 'NNP'), (',', ','), ('and', 'CC'), ('Bunting', 'NNP'), (',', ','), ('M.', 'NNP'), ('(', '('), ('2014', 'CD'), (')', ')'), ('.', '.'), ('Working', 'VBG'), ('memory', 'NN'), ('and', 'CC'), ('second', 'JJ'), ('language', 'NN'), ('comprehension', 'NN'), ('and', 'CC'), ('production', 'NN'), (':', ':'), ('a', 'DT'), ('meta-analysis', 'NN'), ('.', '.'), ('Psychon', 'NNP'), ('.', '.'), ('Bull', 'NNP'), ('.', '.'), ('Rev', 'NNP'), ('.', '.'), ('21', 'CD'), (',', ','), ('861–883', 'CD'), ('.', '.'), ('doi', 'NN'), (':', ':'), ('10.3758/s13423-013-0565-2', 'JJ')]
# POS-tagged paragraph:  [('PubMed', 'NNP'), ('Abstract', 'NNP'), ('|', 'NNP'), ('CrossRef', 'NNP'), ('Full', 'NNP'), ('Text', 'NNP'), ('|', 'NNP'), ('Google', 'NNP'), ('Scholar', 'NNP')]
# ...
# POS-tagged paragraph:  [('Pashler', 'NNP'), (',', ','), ('H.', 'NNP'), (',', ','), ('McDaniel', 'NNP'), (',', ','), ('M.', 'NNP'), (',', ','), ('Rohrer', 'NNP'), (',', ','), ('D.', 'NNP'), (',', ','), ('and', 'CC'), ('Bjork', 'NNP'), (',', ','), ('R.', 'NNP'), ('(', '('), ('2008', 'CD'), (')', ')'), ('.', '.'), ('Learning', 'VBG'), ('styles', 'NNS'), (':', ':'), ('concepts', 'NNS'), ('and', 'CC'), ('evidence', 'NN'), ('.', '.'), ('Psychol', 'NNP'), ('.', '.'), ('Sci', 'NNP'), ('.', '.'), ('Public', 'JJ'), ('Interest', 'NNP'), ('9', 'CD'), (',', ','), ('105–119', 'CD'), ('.', '.'), ('doi', 'NN'), (':', ':'), ('10.1111/j.1539-6053.2009.01038.x', 'JJ')]
# POS-tagged paragraph:  [('PubMed', 'NNP'), ('Abstract', 'NNP'), ('|', 'NNP'), ('CrossRef', 'NNP'), ('Full', 'NNP'), ('Text', 'NNP'), ('|', 'NNP'), ('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('Paulhus', 'NNP'), (',', ','), ('D.', 'NNP'), ('L.', 'NNP'), (',', ','), ('and', 'CC'), ('Vazire', 'NNP'), (',', ','), ('S.', 'NNP'), ('(', '('), ('2007', 'CD'), (')', ')'), ('.', '.'), ('“', 'VB'), ('The', 'DT'), ('self-report', 'JJ'), ('method', 'NN'), (',', ','), ('”', 'NN'), ('in', 'IN'), ('Handbook', 'NNP'), ('of', 'IN'), ('Research', 'NNP'), ('Methods', 'NNP'), ('in', 'IN'), ('Personality', 'NNP'), ('Psychology', 'NNP'), (',', ','), ('eds', 'VBZ'), ('R.', 'NNP'), ('W.', 'NNP'), ('Robins', 'NNP'), (',', ','), ('R.', 'NNP'), ('C.', 'NNP'), ('Fraley', 'NNP'), (',', ','), ('and', 'CC'), ('R.', 'NNP'), ('Krueger', 'NNP'), ('(', '('), ('New', 'NNP'), ('York', 'NNP'), (',', ','), ('NY', 'NNP'), (':', ':'), ('Guilford', 'NNP'), (')', ')'), (',', ','), ('224–239', 'CD'), ('.', '.')]
# POS-tagged paragraph:  [('Pulvermüller', 'NNP'), (',', ','), ('F.', 'NNP'), (',', ','), ('and', 'CC'), ('Fadiga', 'NNP'), (',', ','), ('L.', 'NNP'), ('(', '('), ('2010', 'CD'), (')', ')'), ('.', '.'), ('Active', 'JJ'), ('perception', 'NN'), (':', ':'), ('sensorimotor', 'NN'), ('circuits', 'NNS'), ('as', 'IN'), ('a', 'DT'), ('cortical', 'JJ'), ('basis', 'NN'), ('for', 'IN'), ('language', 'NN'), ('.', '.'), ('Nat', 'NNP'), ('.', '.'), ('Rev', 'NNP'), ('.', '.'), ('Neurosci', 'NNP'), ('.', '.'), ('11', 'CD'), (',', ','), ('351–360', 'CD'), ('.', '.'), ('doi', 'NN'), (':', ':'), ('10.1038/nrn2811', 'CD')]
# POS-tagged paragraph:  [('PubMed', 'NNP'), ('Abstract', 'NNP'), ('|', 'NNP'), ('CrossRef', 'NNP'), ('Full', 'NNP'), ('Text', 'NNP'), ('|', 'NNP'), ('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('Rogowsky', 'NNP'), (',', ','), ('B', 'NNP'), ('.', '.'), ('A.', 'NNP'), (',', ','), ('Calhoun', 'NNP'), (',', ','), ('B.', 'NNP'), ('M.', 'NNP'), (',', ','), ('and', 'CC'), ('Tallal', 'NNP'), (',', ','), ('P.', 'NNP'), ('(', '('), ('2015', 'CD'), (')', ')'), ('.', '.'), ('Matching', 'VBG'), ('learning', 'VBG'), ('style', 'NN'), ('to', 'TO'), ('instructional', 'JJ'), ('method', 'NN'), (':', ':'), ('effects', 'NNS'), ('on', 'IN'), ('comprehension', 'NN'), ('.', '.'), ('J.', 'NNP'), ('Educ', 'NNP'), ('.', '.'), ('Psychol', 'NNP'), ('.', '.'), ('107', 'CD'), (',', ','), ('64–78', 'CD'), ('.', '.'), ('doi', 'NN'), (':', ':'), ('10.1037/a0037478', 'CD')]
# POS-tagged paragraph:  [('CrossRef', 'NNP'), ('Full', 'NNP'), ('Text', 'NNP'), ('|', 'NNP'), ('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('Romanelli', 'NNP'), (',', ','), ('F.', 'NNP'), (',', ','), ('Bird', 'NNP'), (',', ','), ('E.', 'NNP'), (',', ','), ('and', 'CC'), ('Ryan', 'NNP'), (',', ','), ('M.', 'NNP'), ('(', '('), ('2009', 'CD'), (')', ')'), ('.', '.'), ('Learning', 'VBG'), ('styles', 'NNS'), (':', ':'), ('a', 'DT'), ('review', 'NN'), ('of', 'IN'), ('theory', 'NN'), (',', ','), ('application', 'NN'), (',', ','), ('and', 'CC'), ('best', 'JJS'), ('practices', 'NNS'), ('.', '.'), ('Am', 'NNP'), ('.', '.'), ('J.', 'NNP'), ('Pharm', 'NNP'), ('.', '.'), ('Educ', 'NNP'), ('.', '.'), ('73', 'CD'), (',', ','), ('09.', 'CD'), ('doi', 'NN'), (':', ':'), ('10.5688/aj730109', 'CD')]
# POS-tagged paragraph:  [('PubMed', 'NNP'), ('Abstract', 'NNP'), ('|', 'NNP'), ('CrossRef', 'NNP'), ('Full', 'NNP'), ('Text', 'NNP'), ('|', 'NNP'), ('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('Sathian', 'JJ'), (',', ','), ('K.', 'NNP'), (',', ','), ('Lacey', 'NNP'), (',', ','), ('S.', 'NNP'), (',', ','), ('Stilla', 'NNP'), (',', ','), ('R.', 'NNP'), (',', ','), ('Gibson', 'NNP'), (',', ','), ('G.', 'NNP'), ('O.', 'NNP'), (',', ','), ('Deshpande', 'NNP'), (',', ','), ('G.', 'NNP'), (',', ','), ('Hu', 'NNP'), (',', ','), ('X.', 'NNP'), (',', ','), ('et', 'RB'), ('al', 'NN'), ('.', '.'), ('(', '('), ('2011', 'CD'), (')', ')'), ('.', '.'), ('Dual', 'NNP'), ('pathways', 'VBZ'), ('for', 'IN'), ('haptic', 'JJ'), ('and', 'CC'), ('visual', 'JJ'), ('perception', 'NN'), ('of', 'IN'), ('spatial', 'JJ'), ('and', 'CC'), ('texture', 'JJ'), ('information', 'NN'), ('.', '.'), ('NeuroImage', 'NN'), ('57', 'CD'), (',', ','), ('462–475', 'CD'), ('.', '.'), ('doi', 'NN'), (':', ':'), ('10.1016/j.neuroimage.2011.05.001', 'CD')]
# POS-tagged paragraph:  [('PubMed', 'NNP'), ('Abstract', 'NNP'), ('|', 'NNP'), ('CrossRef', 'NNP'), ('Full', 'NNP'), ('Text', 'NNP'), ('|', 'NNP'), ('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('Seghier', 'NNP'), (',', ','), ('M.', 'NNP'), ('L.', 'NNP'), ('(', '('), ('2012', 'CD'), (')', ')'), ('.', '.'), ('The', 'DT'), ('angular', 'JJ'), ('gyrus', 'NN'), (':', ':'), ('multiple', 'JJ'), ('functions', 'NNS'), ('and', 'CC'), ('multiple', 'JJ'), ('subdivisions', 'NNS'), ('.', '.'), ('Neuroscientist', 'NN'), ('19', 'CD'), (',', ','), ('43–61', 'CD'), ('.', '.'), ('doi', 'NN'), (':', ':'), ('10.1177/1073858412440596', 'CD')]
# POS-tagged paragraph:  [('PubMed', 'NNP'), ('Abstract', 'NNP'), ('|', 'NNP'), ('CrossRef', 'NNP'), ('Full', 'NNP'), ('Text', 'NNP'), ('|', 'NNP'), ('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('Seitz', 'NNP'), (',', ','), ('A.', 'NNP'), ('R.', 'NNP'), (',', ','), ('Kim', 'NNP'), (',', ','), ('R.', 'NNP'), (',', ','), ('and', 'CC'), ('Shams', 'NNP'), (',', ','), ('L.', 'NNP'), ('(', '('), ('2006', 'CD'), (')', ')'), ('.', '.'), ('Sound', 'JJ'), ('facilitates', 'VBZ'), ('visual', 'JJ'), ('learning', 'NN'), ('.', '.'), ('Curr', 'NNP'), ('.', '.'), ('Biol', 'NNP'), ('.', '.'), ('16', 'CD'), (',', ','), ('1422–1427', 'CD'), ('.', '.'), ('doi', 'NN'), (':', ':'), ('10.1016/j.cub.2006.05.048', 'CD')]
# POS-tagged paragraph:  [('PubMed', 'NNP'), ('Abstract', 'NNP'), ('|', 'NNP'), ('CrossRef', 'NNP'), ('Full', 'NNP'), ('Text', 'NNP'), ('|', 'NNP'), ('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('Shams', 'NNP'), (',', ','), ('L.', 'NNP'), (',', ','), ('and', 'CC'), ('Seitz', 'NNP'), (',', ','), ('A.', 'NNP'), ('R.', 'NNP'), ('(', '('), ('2008', 'CD'), (')', ')'), ('.', '.'), ('Benefits', 'NNS'), ('of', 'IN'), ('multisensory', 'NN'), ('learning', 'NN'), ('.', '.'), ('Trends', 'VBZ'), ('Cogn', 'NNP'), ('.', '.'), ('Sci', 'NNP'), ('.', '.'), ('12', 'CD'), (',', ','), ('411–417', 'CD'), ('.', '.'), ('doi', 'NN'), (':', ':'), ('10.1016/j.tics.2008.07.006', 'CD')]
# POS-tagged paragraph:  [('PubMed', 'NNP'), ('Abstract', 'NNP'), ('|', 'NNP'), ('CrossRef', 'NNP'), ('Full', 'NNP'), ('Text', 'NNP'), ('|', 'NNP'), ('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('Shimojo', 'NNP'), (',', ','), ('S.', 'NNP'), (',', ','), ('and', 'CC'), ('Shams', 'NNP'), (',', ','), ('L.', 'NNP'), ('(', '('), ('2001', 'CD'), (')', ')'), ('.', '.'), ('Sensory', 'JJ'), ('modalities', 'NNS'), ('are', 'VBP'), ('not', 'RB'), ('separate', 'JJ'), ('modalities', 'NNS'), (':', ':'), ('plasticity', 'NN'), ('and', 'CC'), ('interactions', 'NNS'), ('.', '.'), ('Curr', 'NNP'), ('.', '.'), ('Opin', 'NNP'), ('.', '.'), ('Neurobiol', 'NNP'), ('.', '.'), ('11', 'CD'), (',', ','), ('505–509', 'CD'), ('.', '.'), ('doi', 'NN'), (':', ':'), ('10.1016/S0959-4388', 'JJ'), ('(', '('), ('00', 'CD'), (')', ')'), ('00241-5', 'NN')]
# POS-tagged paragraph:  [('PubMed', 'NNP'), ('Abstract', 'NNP'), ('|', 'NNP'), ('CrossRef', 'NNP'), ('Full', 'NNP'), ('Text', 'NNP'), ('|', 'NNP'), ('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('Takashima', 'NNP'), (',', ','), ('A.', 'NNP'), (',', ','), ('Bakker', 'NNP'), (',', ','), ('I.', 'NNP'), (',', ','), ('van', 'NN'), ('Hell', 'NNP'), (',', ','), ('J.', 'NNP'), ('G.', 'NNP'), (',', ','), ('Janzen', 'NNP'), (',', ','), ('G.', 'NNP'), (',', ','), ('and', 'CC'), ('McQueen', 'NNP'), (',', ','), ('J.', 'NNP'), ('M.', 'NNP'), ('(', '('), ('2014', 'CD'), (')', ')'), ('.', '.'), ('Richness', 'NNP'), ('of', 'IN'), ('information', 'NN'), ('about', 'IN'), ('novel', 'NN'), ('words', 'NNS'), ('influences', 'VBZ'), ('how', 'WRB'), ('episodic', 'JJ'), ('and', 'CC'), ('semantic', 'JJ'), ('memory', 'NN'), ('networks', 'NNS'), ('interact', 'VBP'), ('during', 'IN'), ('lexicalization', 'NN'), ('.', '.'), ('NeuroImage', 'NN'), ('84', 'CD'), (',', ','), ('265–278', 'CD'), ('.', '.'), ('doi', 'NN'), (':', ':'), ('10.1016/j.neuroimage.2013.08.023', 'CD')]
# POS-tagged paragraph:  [('PubMed', 'NNP'), ('Abstract', 'NNP'), ('|', 'NNP'), ('CrossRef', 'NNP'), ('Full', 'NNP'), ('Text', 'NNP'), ('|', 'NNP'), ('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('Thelen', 'NNP'), (',', ','), ('A.', 'NNP'), (',', ','), ('and', 'CC'), ('Murray', 'NNP'), (',', ','), ('M.', 'NNP'), ('M.', 'NNP'), ('(', '('), ('2013', 'CD'), (')', ')'), ('.', '.'), ('The', 'DT'), ('efficacy', 'NN'), ('of', 'IN'), ('single-trial', 'JJ'), ('multisensory', 'NN'), ('memories', 'NNS'), ('.', '.'), ('Multisens', 'NNP'), ('.', '.'), ('Res', 'NNP'), ('.', '.'), ('26', 'CD'), (',', ','), ('483–502', 'CD'), ('.', '.'), ('doi', 'NN'), (':', ':'), ('10.1163/22134808-00002426', 'JJ')]
# POS-tagged paragraph:  [('PubMed', 'NNP'), ('Abstract', 'NNP'), ('|', 'NNP'), ('CrossRef', 'NNP'), ('Full', 'NNP'), ('Text', 'NNP'), ('|', 'NNP'), ('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('Vazire', 'NNP'), (',', ','), ('S.', 'NNP'), (',', ','), ('and', 'CC'), ('Solomon', 'NNP'), (',', ','), ('B.', 'NNP'), ('C.', 'NNP'), ('(', '('), ('2015', 'CD'), (')', ')'), ('.', '.'), ('“', 'CC'), ('Self', 'NNP'), ('and', 'CC'), ('other', 'JJ'), ('knowledge', 'NN'), ('of', 'IN'), ('personality', 'NN'), (',', ','), ('”', 'NN'), ('in', 'IN'), ('APA', 'NNP'), ('Handbook', 'NNP'), ('of', 'IN'), ('Personality', 'NNP'), ('and', 'CC'), ('Social', 'NNP'), ('Psychology', 'NNP'), (',', ','), ('Vol', 'NNP'), ('.', '.'), ('4', 'CD'), (':', ':'), ('Personality', 'NN'), ('Processes', 'VBZ'), ('and', 'CC'), ('Individual', 'NNP'), ('Differences', 'NNP'), ('.', '.'), ('APA', 'NNP'), ('Handbooks', 'NNP'), ('in', 'IN'), ('Psychology', 'NNP'), (',', ','), ('eds', 'VBZ'), ('M.', 'NNP'), ('Mikulincer', 'NNP'), (',', ','), ('P.', 'NNP'), ('R.', 'NNP'), ('Shaver', 'NNP'), (',', ','), ('M.', 'NNP'), ('L.', 'NNP'), ('Cooper', 'NNP'), (',', ','), ('and', 'CC'), ('R.', 'NNP'), ('J.', 'NNP'), ('Larsen', 'NNP'), ('(', '('), ('Washington', 'NNP'), (',', ','), ('DC', 'NNP'), (':', ':'), ('American', 'NNP'), ('Psychological', 'NNP'), ('Association', 'NNP'), (')', ')'), (',', ','), ('261–281', 'CD'), ('.', '.')]
# POS-tagged paragraph:  [('Wei', 'NNP'), (',', ','), ('M.', 'NNP'), (',', ','), ('Joshi', 'NNP'), (',', ','), ('A', 'NNP'), ('.', '.'), ('A.', 'NNP'), (',', ','), ('Zhang', 'NNP'), (',', ','), ('M.', 'NNP'), (',', ','), ('Mei', 'NNP'), (',', ','), ('L.', 'NNP'), (',', ','), ('Manis', 'NNP'), (',', ','), ('F.', 'NNP'), ('R.', 'NNP'), (',', ','), ('He', 'PRP'), (',', ','), ('Q.', 'NNP'), (',', ','), ('et', 'RB'), ('al', 'NN'), ('.', '.'), ('(', '('), ('2015', 'CD'), (')', ')'), ('.', '.'), ('How', 'WRB'), ('age', 'NN'), ('of', 'IN'), ('acquisition', 'NN'), ('influences', 'NNS'), ('brain', 'NN'), ('architecture', 'NN'), ('in', 'IN'), ('bilinguals', 'NNS'), ('.', '.'), ('J.', 'NNP'), ('Neurolinguist', 'NNP'), ('.', '.'), ('36', 'CD'), (',', ','), ('35–55', 'CD'), ('.', '.'), ('doi', 'NN'), (':', ':'), ('10.1016/j.jneuroling.2015.05.001', 'CD')]
# POS-tagged paragraph:  [('CrossRef', 'NNP'), ('Full', 'NNP'), ('Text', 'NNP'), ('|', 'NNP'), ('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('Yuan', 'NN'), (',', ','), ('Y.', 'NNP'), (',', ','), ('and', 'CC'), ('Brown', 'NNP'), (',', ','), ('S.', 'NNP'), ('(', '('), ('2015', 'CD'), (')', ')'), ('.', '.'), ('Drawing', 'VBG'), ('and', 'CC'), ('writing', 'VBG'), (':', ':'), ('an', 'DT'), ('ALE', 'NNP'), ('meta-analysis', 'NN'), ('of', 'IN'), ('sensorimotor', 'NN'), ('activations', 'NNS'), ('.', '.'), ('Brain', 'NNP'), ('Cogn', 'NNP'), ('.', '.'), ('98', 'CD'), (',', ','), ('15–26', 'CD'), ('.', '.'), ('doi', 'NN'), (':', ':'), ('10.1016/j.bandc.2015.05.004', 'CD')]
# POS-tagged paragraph:  [('PubMed', 'NNP'), ('Abstract', 'NNP'), ('|', 'NNP'), ('CrossRef', 'NNP'), ('Full', 'NNP'), ('Text', 'NNP'), ('|', 'NNP'), ('Google', 'NNP'), ('Scholar', 'NNP')]
# POS-tagged paragraph:  [('Keywords', 'NNS'), (':', ':'), ('learning', 'NN'), ('style', 'NN'), (',', ','), ('language', 'NN'), ('learning', 'NN'), (',', ','), ('vocabulary', 'JJ'), ('acquisition', 'NN'), (',', ','), ('brain', 'NN'), (',', ','), ('sensorimotor', 'NN'), ('learning', 'NN'), (',', ','), ('second', 'JJ'), ('language', 'NN'), ('acquisition', 'NN'), (',', ','), ('embodiment', 'NN'), ('and', 'CC'), ('grounded', 'VBD'), ('cognition', 'NN')]
# POS-tagged paragraph:  [('Citation', 'NN'), (':', ':'), ('Macedonia', 'NNP'), ('M', 'NNP'), ('(', '('), ('2015', 'CD'), (')', ')'), ('Learning', 'VBG'), ('Styles', 'NNP'), ('and', 'CC'), ('Vocabulary', 'NNP'), ('Acquisition', 'NNP'), ('in', 'IN'), ('Second', 'NNP'), ('Language', 'NNP'), (':', ':'), ('How', 'WRB'), ('the', 'DT'), ('Brain', 'NNP'), ('Learns', 'NNP'), ('.', '.'), ('Front', 'NNP'), ('.', '.'), ('Psychol', 'NNP'), ('.', '.'), ('6:1800.', 'CD'), ('doi', 'NN'), (':', ':'), ('10.3389/fpsyg.2015.01800', 'CD')]
# POS-tagged paragraph:  [('Received', 'VBN'), (':', ':'), ('18', 'CD'), ('August', 'NNP'), ('2015', 'CD'), (';', ':'), ('Accepted', 'VBN'), (':', ':'), ('09', 'CD'), ('November', 'NNP'), ('2015', 'CD'), (';', ':'), ('Published', 'VBN'), (':', ':'), ('25', 'CD'), ('November', 'NNP'), ('2015', 'CD'), ('.', '.')]
# POS-tagged paragraph:  [('Edited', 'VBN'), ('by', 'IN'), (':', ':')]
# POS-tagged paragraph:  [('Reviewed', 'VBN'), ('by', 'IN'), (':', ':')]
# POS-tagged paragraph:  [('Copyright', 'NNP'), ('©', 'NN'), ('2015', 'CD'), ('Macedonia', 'NNP'), ('.', '.'), ('This', 'DT'), ('is', 'VBZ'), ('an', 'DT'), ('open-access', 'JJ'), ('article', 'NN'), ('distributed', 'VBN'), ('under', 'IN'), ('the', 'DT'), ('terms', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('Creative', 'JJ'), ('Commons', 'NNPS'), ('Attribution', 'NNP'), ('License', 'NNP'), ('(', '('), ('CC', 'NNP'), ('BY', 'NNP'), (')', ')'), ('.', '.'), ('The', 'DT'), ('use', 'NN'), (',', ','), ('distribution', 'NN'), ('or', 'CC'), ('reproduction', 'NN'), ('in', 'IN'), ('other', 'JJ'), ('forums', 'NNS'), ('is', 'VBZ'), ('permitted', 'VBN'), (',', ','), ('provided', 'VBD'), ('the', 'DT'), ('original', 'JJ'), ('author', 'NN'), ('(', '('), ('s', 'JJ'), (')', ')'), ('or', 'CC'), ('licensor', 'NN'), ('are', 'VBP'), ('credited', 'VBN'), ('and', 'CC'), ('that', 'IN'), ('the', 'DT'), ('original', 'JJ'), ('publication', 'NN'), ('in', 'IN'), ('this', 'DT'), ('journal', 'NN'), ('is', 'VBZ'), ('cited', 'VBN'), (',', ','), ('in', 'IN'), ('accordance', 'NN'), ('with', 'IN'), ('accepted', 'JJ'), ('academic', 'JJ'), ('practice', 'NN'), ('.', '.'), ('No', 'DT'), ('use', 'NN'), (',', ','), ('distribution', 'NN'), ('or', 'CC'), ('reproduction', 'NN'), ('is', 'VBZ'), ('permitted', 'VBN'), ('which', 'WDT'), ('does', 'VBZ'), ('not', 'RB'), ('comply', 'VB'), ('with', 'IN'), ('these', 'DT'), ('terms', 'NNS'), ('.', '.')]
# POS-tagged paragraph:  [('*', 'JJ'), ('Correspondence', 'NN'), (':', ':'), ('Manuela', 'NNP'), ('Macedonia', 'NNP'), (',', ','), ('manuela', 'NN'), ('@', 'NNP'), ('macedonia.at', 'NN')]
# POS-tagged paragraph:  [('Suggest', 'NNP'), ('a', 'DT'), ('Research', 'NNP'), ('Topic', 'NNP'), ('>', 'VBD')]

# %%
paragraphs = soup.find_all('p')

from nltk.tokenize import WordPunctTokenizer
tokenizer = WordPunctTokenizer()
for parts in paragraphs:
    text = parts.get_text().strip()
    if len(text) > 0:
        print("The number of words in each paragraph: ", len(tokenizer.tokenize(text)))
# Out:
# The number of words in each paragraph:  13
# The number of words in each paragraph:  5
# The number of words in each paragraph:  5
# The number of words in each paragraph:  27
# The number of words in each paragraph:  5
# The number of words in each paragraph:  5
# The number of words in each paragraph:  220
# The number of words in each paragraph:  573
# The number of words in each paragraph:  325
# The number of words in each paragraph:  48
# The number of words in each paragraph:  133
# The number of words in each paragraph:  172
# The number of words in each paragraph:  412
# The number of words in each paragraph:  354
# The number of words in each paragraph:  137
# The number of words in each paragraph:  28
# The number of words in each paragraph:  41
# The number of words in each paragraph:  6
# The number of words in each paragraph:  72
# The number of words in each paragraph:  9
# The number of words in each paragraph:  40
# The number of words in each paragraph:  9
# The number of words in each paragraph:  59
# The number of words in each paragraph:  9
# The number of words in each paragraph:  48
# The number of words in each paragraph:  9
# The number of words in each paragraph:  70
# The number of words in each paragraph:  9
# The number of words in each paragraph:  59
# The number of words in each paragraph:  9
# The number of words in each paragraph:  55
# The number of words in each paragraph:  6
# The number of words in each paragraph:  47
# The number of words in each paragraph:  9
# The number of words in each paragraph:  56
# The number of words in each paragraph:  9
# The number of words in each paragraph:  29
# The number of words in each paragraph:  23
# The number of words in each paragraph:  42
# The number of words in each paragraph:  9
# The number of words in each paragraph:  61
# The number of words in each paragraph:  9
# The number of words in each paragraph:  50
# The number of words in each paragraph:  9
# The number of words in each paragraph:  33
# The number of words in each paragraph:  2
# The number of words in each paragraph:  45
# The number of words in each paragraph:  9
# The number of words in each paragraph:  24
# The number of words in each paragraph:  2
# The number of words in each paragraph:  64
# The number of words in each paragraph:  9
# The number of words in each paragraph:  66
# The number of words in each paragraph:  9
# The number of words in each paragraph:  28
# The number of words in each paragraph:  2
# The number of words in each paragraph:  56
# The number of words in each paragraph:  9
# The number of words in each paragraph:  59
# The number of words in each paragraph:  9
# The number of words in each paragraph:  44
# The number of words in each paragraph:  9
# The number of words in each paragraph:  61
# The number of words in each paragraph:  6
# The number of words in each paragraph:  42
# The number of words in each paragraph:  9
# The number of words in each paragraph:  48
# The number of words in each paragraph:  6
# The number of words in each paragraph:  53
# The number of words in each paragraph:  9
# The number of words in each paragraph:  63
# The number of words in each paragraph:  9
# The number of words in each paragraph:  58
# The number of words in each paragraph:  9
# The number of words in each paragraph:  54
# The number of words in each paragraph:  9
# The number of words in each paragraph:  75
# The number of words in each paragraph:  9
# The number of words in each paragraph:  73
# The number of words in each paragraph:  36
# The number of words in each paragraph:  6
# The number of words in each paragraph:  56
# The number of words in each paragraph:  9
# The number of words in each paragraph:  59
# The number of words in each paragraph:  43
# The number of words in each paragraph:  9
# The number of words in each paragraph:  50
# The number of words in each paragraph:  6
# The number of words in each paragraph:  49
# The number of words in each paragraph:  9
# The number of words in each paragraph:  67
# The number of words in each paragraph:  9
# The number of words in each paragraph:  33
# The number of words in each paragraph:  9
# The number of words in each paragraph:  48
# The number of words in each paragraph:  9
# The number of words in each paragraph:  45
# The number of words in each paragraph:  9
# The number of words in each paragraph:  50
# The number of words in each paragraph:  9
# The number of words in each paragraph:  68
# The number of words in each paragraph:  9
# The number of words in each paragraph:  42
# The number of words in each paragraph:  9
# The number of words in each paragraph:  82
# The number of words in each paragraph:  69
# The number of words in each paragraph:  6
# The number of words in each paragraph:  49
# The number of words in each paragraph:  9
# The number of words in each paragraph:  24
# The number of words in each paragraph:  40
# The number of words in each paragraph:  18
# The number of words in each paragraph:  3
# The number of words in each paragraph:  3
# The number of words in each paragraph:  83
# The number of words in each paragraph:  11
# The number of words in each paragraph:  5

# %% [markdown]
# ### Chapter 3.
#
# From the previous part of this work, you can find the information on linguistically-analysed text from a website. How come is it supposed to be helpful, you may ask. For the sake of this essay, meaning the role of vocabulary acquisition in English learning, we are able to indicate a few applications:
#
# 1. From extracting the most common words in each paragraph we can distinguish those, we do not know and check them out (as it was mentioned in Chapter 1.).
# 2. The same situation occurs in POS-tagging analysis, we can see examples of words, distinguish those we do know know, but here we can simultaneously the information on a part of speech in a sentence. From that, we can guess the meaning of a word easier from the context, given we already know if it is a noun, a verb or an adjective.
#
# Furthermore, the analysis confirms the data displayed in the pie chart. Reading and analysing sentences help us learn new words or just extends our current vocabulary to sound more like *native speaker*.
